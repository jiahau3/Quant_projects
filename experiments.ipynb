# %%
from bs4 import BeautifulSoup
from datetime import datetime
import json
import numpy as np
import os
import pandas as pd
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
def get_keys(path):
    """
    This function will get dictionary of keys from a stored json file
    :param path: (str) directory path for the .json file with keys
    """
    with open(path) as f:
        return json.load(f)

def search_symbol(driver, ticker):
    """
    This function searches for a ticker symbol on TD Ameritrade website once
    user is logged in.
    :param driver: (Selenium webdriver) webdriver returned from start_bot()
    :param ticker: (str) ticker symbol to search
    """

    # Attempt the more expedient symbol lookup, rever to main search otherwise
    try:
        search = driver.find_element(By.XPATH, '//*[@id="symbol-lookup"]')
        search.click()
        search.clear()
    except:
        driver.switch_to.default_content()
        search = driver.find_element(By.NAME, "search")
        kind = 'search'
    else:
        kind = 'symbol'
    # Enter ticker symbol to search and click search button
    search.send_keys(ticker)
    if kind == 'symbol':
        driver.find_element(By.XPATH, '//*[@id="layout-full"]/div[1]/div/div[1]/div/a').click()
    elif kind == 'search':
        driver.find_element(By.ID ,"searchIcon").click()
    # Give extra time for webpage to load
    time.sleep(4)

def reduce_tabs(driver):
    """
    This function is used when an action opens the result on a new tab, in
    order to reduce the number of browser tabs back to 1, and switch to the
    intended tab.
    :param driver: (Selenium webdriver)
    """
    if len(driver.window_handles) > 1:
        driver.switch_to.window(driver.window_handles[0])
        driver.close()
        driver.switch_to.window(driver.window_handles[0])

def clean(x, show_errors=False):
    """
    This function is used to clean strings containing numeric data of the 
    common issues found in TD Ameritrade's website
    """
    #print("cleaning {} of type {}".format(x, type(x)))
    not_date = True
    multiple = 1
    if isinstance(x, str):
        check = re.split('/|-|, ', x)
        x = x.strip()
        x = x.replace(',','')

        if x.startswith('(') and x.endswith(')'):
            x = x.strip('(').strip(')')
            x = '-'+x

        if x.endswith('%'):
            x = x.replace('%','')
            multiple = 1/100
        elif x.endswith('x'):
            x = x.strip('x')
            if x == '--':
                x = np.NaN
            else:
                x = x

        if x.endswith('k') or x.endswith('K'):
            x = x.upper().replace('K','')
            multiple = 1000

        if x.startswith('$') or x.startswith('-$'):
            x = x.replace('$','')
        elif len(check) > 1 and check[-1].isdigit():
            not_date = False
            if x.startswith('(Unconfirmed)'):
                x = x.replace('(Unconfirmed) ','')
            x = pd.to_datetime(x, infer_datetime_format=True)

        if x == '--':
            x = np.NaN

        if not_date:
            try:
                x = float(x) * multiple
            except:
                if show_errors:
                    print(x) 
                x = np.NaN
    #print('returning {}'.format(x))
    return x   

def start_bot(keys):
    """
    Starts TD Ameritrade Scraping Bot. Takes input of dictionary containing 
    username and password which must have keys "user" and "pass" with the 
    values to be used. Returns webdriver object to be used for session.
    :param keys: (dict) dictionary with username ("user") and password ("pass")
    """
    driver = webdriver.Chrome()
    #driver.implicitly_wait(20)
    login_url = 'https://invest.ameritrade.com/grid/p/login'
    try:
        driver.get(login_url)
    except:
        raise ValueError('Caanot find Login button')
    else:
        assert "TD Ameritrade Login" in driver.title
        WebDriverWait(driver, 10).until(lambda x: x.find_element(By.CSS_SELECTOR, 'button.cafeLoginButton')).click()
        username = WebDriverWait(driver, 10).until(lambda x: x.find_element(By.ID, 'username0'))
        username.send_keys(keys["user"])
        password = WebDriverWait(driver, 10).until(lambda x: x.find_element(By.ID, "password1"))
        password.send_keys(keys["pass"])
        try:
            driver.find_element(By.CSS_SELECTOR, 'input#accept.accept.button').click()
        except:
            raise ValueError("Login fails.")
        else:
            try:
                WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Use desktop website'))
                time.sleep(3)
                button = WebDriverWait(driver, 10).until(lambda x: x.find_element(By.XPATH, value='//*[@id="app"]/div/div[2]/footer/div/ul/li[1]/button'))
                button.click()
                time.sleep(3)
                home_url = driver.current_url
                reduce_tabs(driver)
            except:
                return driver

    return driver

def scrape_summary(driver, ticker, search_first=True, return_full=False, internet_speed='fast'):
    """
    This function scrapes the "Summary" tab of a TD Ameritrade security
    lookup page
    :param driver: (Selenium webdriver) webdriver returned from start_bot()
    :param ticker: (str) ticker symbol to scrape
    :param search_first: (bool) allows for chain of scrapes to be done on one
                                security when set to False. Leave set to True
                                unless you are sure you are already on the
                                desired security, or the wrong data will scrape
    :param return_full: (bool) will return dataframe with extra column containing
                               feature descriptions for the rows.
    :param internet_speed: (str) set to 'slow' if bot is not working properly due
                                to slow page loading times.
    """
    # Search symbol first if flag is True:
    if search_first:
        search_symbol(driver, ticker)
        if internet_speed == 'slow':
            time.sleep(1)
    #tabs = get_tab_links()
    #driver.get(tabs['Summary'])

    if internet_speed == 'fast':
        sleep_time = 1
    elif internet_speed == 'slow':
        sleep_time = 2

    # Find main iframe
    driver.switch_to.default_content()
    iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
    driver.switch_to.frame(iframes[3])

    # Switch to Summary tab
    WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Summary'))
    WebDriverWait(driver, 10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/nav/ul/li[1]/a')).click()
    
    # Wait for conditions to be met before making soup
    element = driver.find_element(By.XPATH, '//*[@id="stock-summarymodule"]/div/div/div[2]/div')
    WebDriverWait(driver, 10).until(lambda x: EC.visibility_of_element_located(element))
    # Add extra time for data to load
    time.sleep(sleep_time)
    
    # Make soup and find elements
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    dts = soup.find_all('dt')

    # Set flag which will be made false if no dividend is given
    dividend_given = True
    texts = []
    for dt in dts:
        try:
            texts.append(dt.get_text('|'))        
        except:
            print("error")
            continue

    dds = soup.find_all('dd')
    values = []
    for dd in dds:
        try:
            values.append(dd.get_text('|'))        
        except:
            print("error")
            continue

    fields = [x.split('|')[0] for x in texts]
    alt_info = [x.split('|')[1:] for x in texts]

    # Make dataframe and fix row names
    data_dict = dict(zip(fields,zip(alt_info,values)))
    temp = pd.DataFrame.from_dict(data_dict, orient='index')
    temp.loc['Volume', 1] = temp.loc['Volume', 0][0].strip()
    temp.rename(index={'Volume:':'Volume 10-day Avg',
                          'Volume':'Volume Past Day',
                          '10-day average volume:':'Volume',
                          'Score:':'New Constructs Score'
                        }, inplace=True)
    temp.loc['52-Wk Range', 1] = temp.loc['52-Wk Range', 0]
    price_feat = 'Closing Price'
    if price_feat not in temp.index:
        if 'Price' in temp.index:
            price_feat = 'Price'

    # Cleaning data
    if temp.loc["B/A Size",1] == '--': 
        temp = temp.append(pd.Series([[],
                                  np.NaN
                                 ],
                                 name="Bid Size"),
                      )
        temp = temp.append(pd.Series([[],
                                  np.NaN
                                 ],
                                 name="Ask Size"),
                      )
        temp = temp.append(pd.Series([[],
                                  np.NaN
                                 ],
                                 name="B/A Ratio"),
                      )
    else:
        temp = temp.append(pd.Series([[],
                                  float(temp.loc['B/A Size',1].split('x')[0])
                                 ],
                                 name="Bid Size"),
                      )
        temp = temp.append(pd.Series([[],
                                  float(temp.loc['B/A Size',1].split('x')[1])
                                 ],
                                 name="Ask Size"),
                      )
        temp = temp.append(pd.Series([[],
                                  float(temp.loc['B/A Size',1].split('x')[0])
                                            /float(temp.loc['B/A Size',1].split('x')[1])
                                 ],
                                 name="B/A Ratio"),
                    )  
    if temp.loc["Day's Range",1] == '--':
        temp = temp.append(pd.Series([[],
                                  np.NaN,
                                 ],
                                 name="Day Change $"
                                ),
                      )
        temp = temp.append(pd.Series([[],
                                  np.NaN
                                 ],
                                 name="Day Change %"
                                ),
                      )
        temp = temp.append(pd.Series([[],
                                 np.NaN
                                 ],
                                name="Day Low"),
                      )
        temp = temp.append(pd.Series([[],
                                 np.NaN
                                 ],
                                name="Day High"),
                      )
    else:
        temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
                                 name="Day Change $"
                                ),
                      )
        temp = temp.append(pd.Series([[],
                                  float(temp.loc["Day's Change",1].split('|')[2].strip('%)').strip('()'))/100
                                 ],
                                 name="Day Change %"
                                ),
                      )
        temp = temp.append(pd.Series([[],
                                 float(temp.loc["Day's Range",1].split('-')[0].strip('|').replace(',',''))
                                 ],
                                name="Day Low"),
                      )
        temp = temp.append(pd.Series([[],
                                 float(temp.loc["Day's Range",1].split('-')[1].strip('|').replace(',',''))
                                 ],
                                name="Day High"),
                      )
    if temp.loc["Annual Dividend/Yield",1] != 'No dividend':
        temp = temp.append(pd.Series([[],
                                 float(temp.loc["Annual Dividend/Yield",1].split('/')[0].strip('$'))
                                 ],
                                name="Annual Dividend $"))

        temp = temp.append(pd.Series([[],
                                 float(temp.loc["Annual Dividend/Yield",1].split('/')[1].strip('%'))/100
                                 ],
                                name="Annual Dividend %"))
    else:
        dividend_given = False
        temp = temp.append(pd.Series([[],
                                 np.NaN
                                 ],
                                name="Annual Dividend $"))
        temp = temp.append(pd.Series([[],
                                 np.NaN
                                 ],
                                name="Annual Dividend %"))
    temp.rename(columns={1:ticker}, inplace = True)
    drop = ["Day's Change", 
            "Day's Range",
            "Day's High",
            "Day's Low",
            "Avg Vol (10-day)", 
            #"52-Wk Range", 
            "Annual Dividend/Yield",
            "New Constructs Score"
            ]

    # Drop feature description column if flag is False (default)
    if return_full == False:
        temp.drop(index=drop, columns=[0], inplace=True, errors='ignore')
    
    # Clean data
    temp = temp.T
    # Only one of these columns will be present:
    try:
        temp['% Below High'] = temp['% Below High'].map(lambda x: float(x.strip('%'))/100, na_action='ignore')
    except:
        temp['% Above Low'] = temp['% Above Low'].map(lambda x: clean(x), na_action='ignore')
    
    temp['% Held by Institutions'] = temp['% Held by Institutions'].map(lambda x: clean(x)/100, na_action='ignore')
    temp['Short Interest'] = temp['Short Interest'].map(lambda x: clean(x)/100, na_action='ignore')
    # Set list of columns for cleaing
    try_to_clean = ['Prev Close',
                    'Ask close',
                    'Bid close',
                    'Beta',
                    'Ask',
                    'Bid',
                    'EPS (TTM, GAAP)',
                    'Last Trade',
                    'Last (size)',
                    price_feat,
                    'Historical Volatility',
                    'P/E Ratio (TTM, GAAP)',
                    "Today's Open",
                    'Volume',
                    'Volume 10-day Avg']
    # Clean columns
    for col in try_to_clean:
        try:
            temp[col] = temp[col].map(lambda x: clean(x), na_action='ignore')
        except:
            pass
    
    # Convert date info to datetime if it exists
    if dividend_given:
        try:
            temp['Ex-dividend'] = pd.to_datetime(temp['Ex-dividend Date'], infer_datetime_format=True)
        except:
            temp['Ex-dividend'] = pd.to_datetime(temp['Ex-dividend'], infer_datetime_format=True)
        temp['Dividend Pay Date'] = pd.to_datetime(temp['Dividend Pay Date'], infer_datetime_format=True)

    # Try to force any remaining numbers to floats:
    temp = temp.astype('float64', errors='ignore')
    temp = temp.T   
    temp.sort_index(inplace=True)

    return temp

def scrape_earnings(driver, ticker, search_first=True, internet_speed='fast'):
    """
    This function scrapes the "Earnings" tab of a TD Ameritrade security
    lookup page
    :param driver: (Selenium webdriver) webdriver returned from start_bot()
    :param ticker: (str) ticker symbol to scrape
    :param search_first: (bool) allows for chain of scrapes to be done on one
                                security when set to False. Leave set to True
                                unless you are sure you are already on the
                                desired security, or the wrong data will scrape
    :param internet_speed: (str) set to 'slow' if bot is not working properly due
                                to slow page loading times.
    """
    # Search for symbol if flag is True
    if search_first:
        search_symbol(driver, ticker)
        if internet_speed == 'slow':
            time.sleep(1)

    if internet_speed == 'fast':
        sleep_time = 1
    elif internet_speed == 'slow':
        sleep_time = 2
    
    # Find main iframe:  
    driver.switch_to.default_content()    
    iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
    driver.switch_to.frame(iframes[3])
    
    # Switch to Earnings tab:
    WebDriverWait(driver,10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/nav/ul/li[4]/a')).click()
    time.sleep(2)
    
    # Switch to Earnings Analysis (1st sub tab)
    WebDriverWait(driver,10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/div[4]/nav/nav/a[1]')).click()
    time.sleep(sleep_time)
    
    # Wait for conditions before making soup
    WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Annual Earnings History and Estimates'))
    element = driver.find_element(By.XPATH, '//*[@id="main-chart-wrapper"]')
    WebDriverWait(driver, 10).until(lambda x: EC.visibility_of_element_located(element))
    
    # Make soup and find container/elements
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    earn_dict = {}
    earnings_dict = {}
    contain = soup.find('div', {'data-module-name':'EarningsAnalysisModule'})
    header = contain.find('div', {'class':'row contain earnings-data'})
    #key = header.find('td', {'class':'label bordered'}).get_text()
    earn_dict['Next Earnings Announcement'] = header.find('td', {'class':'value week-of'}).get_text()
    
    # Get number of analysts reporting on security
    analysts = header.find_all('td', {'class':'label'})[1].get_text().split()
    for word in analysts:
        # The number of analysts will be the only numerical string
        try:
            earn_dict['Growth Analysts'] = float(word)
        except:
            continue
    # Find chart object in container, then bars
    chart = contain.find('div', {'id':'main-chart-wrapper'})
    bars = chart.find_all('div', {'class':'ui-tooltip'})
    for bar in bars:
        text = bar.get_text('|').split('|')
        # text[0] is the year
        year = text[0]
        earnings_dict[year] = {}
        # There is more text when there is a earnings surprise
        if len(text) > 4:
            earnings_dict[year]['Earnings Result'] = text[1]
            earnings_dict[year][text[2].strip('"').strip().strip(':')] = float(text[3].replace('$',''))
            earnings_dict[year][text[4].split(':')[0]] = text[4].split(':')[1].strip()
        else:
            earnings_dict[year]['Earnings Result'] = 'Neutral'
            # Should be a string: 'Actual' or 'Estimate'
            est_string = text[1].strip('"').strip().strip(':')
            # The actual consensus estimate
            est = float(text[2].replace('$',''))
            earnings_dict[year][est_string] = est
            # Should be a string: 'Estimate range'
            est_range_string = text[3].split(':')[0]
            # The estimate range as a string
            est_range = text[3].split(':')[1].strip()
            # Convert to 
            earnings_dict[year][est_range_string] = est_range
            
    # Create df and all useful columns
    earnings_yrly = pd.DataFrame.from_dict(earnings_dict, orient='index')
    earnings_yrly['Growth'] = earnings_yrly['Actual'].pct_change()
    earnings_yrly['Low Estimate'] = earnings_yrly['Estimate range'].map(lambda x: float(x.split()[0].replace('$','')), na_action='ignore')
    earnings_yrly['Low Growth Est'] = earnings_yrly['Low Estimate'].pct_change()
    earnings_yrly['High Estimate'] = earnings_yrly['Estimate range'].map(lambda x: float(x.split()[2].replace('$','')), na_action='ignore')
    earnings_yrly['High Growth Est'] = earnings_yrly['High Estimate'].pct_change()
    # Take average of high and low for years where 'Estimate' not available
    earnings_yrly['Consensus Estimate'] = (earnings_yrly['High Estimate'] + earnings_yrly['Low Estimate']) / 2
    # Supercede these values where consensus estimates are available
    idx_to_change = earnings_yrly[earnings_yrly['Estimate'].notnull()].index
    earnings_yrly.loc[idx_to_change, 'Consensus Estimate'] = earnings_yrly.loc[idx_to_change, 'Estimate']
    # Make new column that contains the actuals and consensus estimates
    earnings_yrly['Actual/Estimate'] = earnings_yrly['Actual']
    earnings_yrly.loc[idx_to_change, 'Actual/Estimate'] = earnings_yrly.loc[idx_to_change, 'Estimate']
    earnings_yrly['A/E Growth'] = earnings_yrly['Actual/Estimate'].pct_change()

    if 'Consensus estimate' in earnings_yrly.columns:
        # Sometimes ranges aren't given, and Consensus estimate given instead, fill holes caused
        earnings_yrly['Consensus Estimate'].fillna(earnings_yrly[earnings_yrly['Consensus estimate'].notnull()]['Consensus estimate'].map(lambda x: float(x.replace('$',''))), inplace=True)
        earnings_yrly.drop(columns=['Consensus estimate'], inplace=True)
    earnings_yrly.drop(columns=['Estimate range'], inplace=True)
    earnings_yrly['Consensus Growth Est'] = (earnings_yrly['High Growth Est']+earnings_yrly['Low Growth Est']) / 2
    
    low_1yr_growth_est = earnings_yrly.iloc[-2,:]['Low Growth Est']
    high_1yr_growth_est = earnings_yrly.iloc[-2,:]['High Growth Est']
    cons_1yr_growth_est = earnings_yrly.iloc[-2,:]['Consensus Growth Est']
    growth_2yr_low_est = earnings_yrly.iloc[-2:]['Low Growth Est'].mean()
    growth_2yr_high_est = earnings_yrly.iloc[-2:]['High Growth Est'].mean()
    growth_2yr_cons_est = (growth_2yr_low_est + growth_2yr_high_est) / 2
    earn_dict['Growth 1yr Low Est'] = low_1yr_growth_est
    earn_dict['Growth 1yr High Est'] = high_1yr_growth_est
    earn_dict['Growth 1yr Consensus Est'] = cons_1yr_growth_est
    earn_dict['Growth 2yr Low Est'] = growth_2yr_low_est
    earn_dict['Growth 2yr High Est'] = growth_2yr_high_est
    earn_dict['Growth 2yr Consensus Est'] = growth_2yr_cons_est
    earn_dict['Growth 5yr Low Est'] = earnings_yrly['Low Growth Est'].mean()
    earn_dict['Growth 5yr High Est'] = earnings_yrly['High Growth Est'].mean()
    earn_dict['Growth 5yr Consensus Est'] = earnings_yrly['Consensus Growth Est'].mean()
    earn_dict['Growth 5yr Actual/Est'] = earnings_yrly['A/E Growth'].mean()
    earn_dict['Growth 3yr Historic'] = earnings_yrly['Growth'].mean()

    earn_df = pd.DataFrame.from_dict(earn_dict, orient='index', columns=[ticker])
    earn_df[ticker] = earn_df[ticker].map(clean)

    return earn_df, earnings_yrly

def scrape_fundamentals(driver, ticker, search_first=True, internet_speed='fast'):
    """
    This function scrapes the "Fundamentals" tab of a TD Ameritrade security
    lookup page
    :param driver: (Selenium webdriver) webdriver returned from start_bot()
    :param ticker: (str) ticker symbol to scrape
    :param search_first: (bool) allows for chain of scrapes to be done on one
                                security when set to False. Leave set to True
                                unless you are sure you are already on the
                                desired security, or the wrong data will scrape
    :param internet_speed: (str) set to 'slow' if bot is not working properly due
                                to slow page loading times.
    """
    # Search symbol first if flag is True
    if search_first:
        search_symbol(driver, ticker)
        #tabs = get_tab_links()
    
    if internet_speed == 'fast':
        sleep_time = 1
    elif internet_speed == 'slow':
        sleep_time = 2
        time.sleep(1)

    # Gets Overview
    driver.switch_to.default_content()
    iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME,"iframe"))
    driver.switch_to.frame(iframes[3])
    WebDriverWait(driver,10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/nav/ul/li[5]/a')).click()
    #time.sleep(1)
    WebDriverWait(driver,10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/div[4]/nav/nav/a[1]')).click()
    time.sleep(sleep_time)
    driver.switch_to.default_content()
    iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
    driver.switch_to.frame(iframes[3])
    #WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Price Performance'))
    #driver.find_element_by_xpath('//*[@id="layout-full"]/nav/ul/li[5]/a').click()
    #time.sleep(1)

    # Wait for conditions before making soup
    WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Price Performance'))
    element = driver.find_element(By.XPATH, '//*[@id="price-charts-wrapper"]/div')
    WebDriverWait(driver, 10).until(lambda x: EC.visibility_of_element_located(element))
      
    # Make soup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Scrapes current valuation ratios
    contain = soup.find('div', {'class': 'ui-description-list'})
    labels = [x.get_text().strip() for x in contain.find_all('dt')]
    values = [float(x.get('data-rawvalue')) for x in contain.find_all('dd')]
    for i, value in enumerate(values):
        if value == '-99999.99' or value == -99999.99:
            values[i] = np.NaN
    fundies = dict(zip(labels,values))

    # Gets 5yr low and high from chart
    contain = soup.find('div', {'class':'col-xs-8 price-history-chart'})
    five_yr = contain.find_all('div', {'class':'marker hideOnHover'})
    fundies['5yr Low'] = five_yr[0].get_text().split(' ')[1]
    fundies['5yr High'] = five_yr[1].get_text().split(' ')[1]

    # Gets 5 year Price Performance data from each hover section of graphic
    periods = contain.find_all('div', {'class':'period'})
    texts = [x.get_text('|') for x in periods]
    past_dict = {}
    yr_growths = []
    for text in texts:
        parts = text.split('|')
        year = parts[2].split(' ')[3].strip()
        past_dict[year] = {}
        high = parts[1].split(' ')[2].strip()
        low = parts[0].split(' ')[2].strip()
        change = parts[2].split(' ')[0].strip()
        past_dict[year]['high'] = high
        past_dict[year]['low'] = low
        past_dict[year]['change'] = change
        yr_growths.append(float(change.strip('%')))
    fundies['5yr Avg Return'] = np.mean(yr_growths) / 100

    # Gets Historic Growth and Share Detail
    contain = soup.find('div', {'data-module-name':'HistoricGrowthAndShareDetailModule'})
    boxes = contain.find_all('div', {'class':'col-xs-4'})
    labels = []
    values = []
    historic_data = True

    for box in boxes:
        numbers = []
        words = []
        if box.find('h4').get_text() == 'Historic Growth':
            for dt in box.find_all('dt')[1:]:
                word = dt.get_text('|').split('|')[0].strip() +' Growth 5yr'
                words.append(word)
            for dd in box.find_all('dd'):
                try:
                    number = float(dd.find('label').get('data-value'))
                    #print(number)
                    if number == -99999.99:
                        #print("here")
                        number = np.NaN
                except:
                    #print("didn't find number")
                    try:
                        number = dd.find('span').get_text()
                    except:
                        number = np.NaN
                #print(number)
                numbers.append(number)
            if len(words) == 0:
                print("Historic Growth not available for {}".format(ticker))
                historic_data = False
        else:
            for dt in box.find_all('dt')[1:]:
                word = dt.get_text('|').split('|')[0].strip()
                words.append(word)
            for dd in box.find_all('dd'):
                try:
                    number = float(dd.get('data-rawvalue'))
                    if number == -99999.99:
                        number = np.NaN
                except:
                    try:
                        number = dd.get_text()
                    except:
                        number = np.NaN
                numbers.append(number)

        labels = labels + words
        values = values + numbers
    
    # Make df of Historic Growth and Share Detail
    fundies2 = dict(zip(labels, values))

    # Get ready to scrape financial reports:
    report_names = ['Balance Sheet',
              'Income Statement',
              'Cash Flow'
             ]
    xpaths = [#'//*[@id="layout-full"]/div[4]/nav/nav/a[1]', # Already done
              '//*[@id="layout-full"]/div[4]/nav/nav/a[2]',
              '//*[@id="layout-full"]/div[4]/nav/nav/a[3]',
              '//*[@id="layout-full"]/div[4]/nav/nav/a[4]'
             ]
    reports = dict(zip(report_names, xpaths))
    
    # Function to scrape each report, since their formats are similar enough
    def scrape_report(name, xpath):
        # Switch to Appropriate Report
        driver.find_element(By.XPATH, xpath).click()
        time.sleep(sleep_time)
        iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
        driver.switch_to.frame(iframes[3])
        driver.switch_to.default_content()
        iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
        driver.switch_to.frame(iframes[3])
        WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Values displayed are in millions.'))
        element = driver.find_element(By.XPATH, '//*[@id="layout-full"]/div[4]/div/div')
        WebDriverWait(driver, 10).until(lambda x: EC.visibility_of_element_located(element))

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        #pprint.pprint(soup)
        contain = soup.find('div', {'data-module-name':'FinancialStatementModule'})
        year_info = [x.get_text('|') for x in contain.find_all('th', {'scope':'col'})]
        years = [x.split('|')[0] for x in year_info]
        dates = [x.split('|')[1] for x in year_info]

        sheet = {}
        for i, year in enumerate(years):
            sheet[year] = {}
            sheet[year]['Date'] = dates[i]
        row_names = []
        contain = soup.find('div', {'class':'row contain data-view'})
        rows = contain.find_all('tr')[1:] # Skips the header row
        #rows = contain.find_all('th', {'scope':'row'})
        for row in rows:
            #print(row)
            row_name = row.get_text('|').split('|')[0]
            row_names.append(row_name)
            values = row.find_all('td')
            for i, value in enumerate(values):
                sheet[years[i]][row_name] = value.get_text()
                
        temp = pd.DataFrame.from_dict(sheet, orient='index').T
        temp['Report'] = name
        return temp
    
    
    # Create summary dataframes
    temp = pd.DataFrame.from_dict(fundies, orient='index', columns=[ticker])
    temp2 = pd.DataFrame.from_dict(fundies2, orient='index', columns=[ticker])
    temp2.rename(index={'Current Month':'Short Int Current Month',
                         'Previous Month':'Short Int Prev Month',
                         'Percent of Float':'Short Int Pct of Float'
                        },
                inplace=True)
    # Clean these rows if they exist
    try:
        temp2.loc['Short Int Pct of Float',:] = temp2.loc['Short Int Pct of Float',:].astype('float64') / 100
        temp2.loc['% Held by Institutions',:] = temp2.loc['% Held by Institutions',:].astype('float64') / 100
    except:
        print("Short Interest info not available for {}".format(ticker))

    # Create yearly dataframe
    yearly = pd.DataFrame.from_dict(past_dict, orient='index').T
    for name, xpath in reports.items():
        tempy = scrape_report(name, xpath)
        yearly = pd.concat([yearly, tempy], axis=0, sort=False)
    
    # Combine two summary dataframes
    temp = pd.concat([temp,temp2], axis=0) 

    # Clean data in the dataframes  
    for col in temp:
        temp[col] = temp[col].map(lambda x: clean(x),  na_action='ignore')
    colnames = [col for col in yearly.columns if col not in ['Report']]
    for col in colnames:
        yearly[col] = yearly[col].map(lambda x: clean(x), na_action='ignore')
    
    # Create FCF and growth features for summary from yearly:
    yearly = yearly.T.astype('float64', errors='ignore')
    temp = temp.T.astype('float64', errors='ignore')
    indices = [indx for indx in yearly.index if indx not in ['Report']]
    yearly['Free Cash Flow'] = np.NaN
    yearly['FCF Growth'] = np.NaN
    # Allows this to not throw errors if values not available
    try:
        yearly.loc[indices,'Free Cash Flow'] = yearly.loc[indices,'Total Cash from Operations'] + yearly['Capital Expenditures']
        yearly.loc[indices,'FCF Growth'] = yearly.loc[indices,'Free Cash Flow'].pct_change()
        temp['FCF Growth 5yr'] = yearly['FCF Growth'].mean()
    except:
        temp['FCF Growth 5yr'] = np.NaN
    # These percentages must be formatted
    if historic_data:
        temp['EPS Growth 5yr'] = temp['EPS Growth 5yr']/100
        temp['Revenue Growth 5yr'] = temp['Revenue Growth 5yr']/100
        temp['Dividend Growth 5yr'] = temp['Dividend Growth 5yr']/100
    else:
        temp['EPS Growth 5yr'] = np.NaN
        temp['Revenue Growth 5yr'] = np.NaN
        temp['Dividend Growth 5yr'] = np.NaN

    # Transposing dataframes back
    temp = temp.T
    yearly = yearly.T

    return temp, yearly

def scrape_valuation(driver, ticker, search_first=True, internet_speed='fast'):
    """
    This function scrapes the "Valuation" tab of a TD Ameritrade security
    lookup page
    :param driver: (Selenium webdriver) webdriver returned from start_bot()
    :param ticker: (str) ticker symbol to scrape
    :param search_first: (bool) allows for chain of scrapes to be done on one
                                security when set to False. Leave set to True
                                unless you are sure you are already on the
                                desired security, or the wrong data will scrape
    :param internet_speed: (str) set to 'slow' if bot is not working properly due
                                to slow page loading times.
    """
    # Search symbol first if flag is True
    if search_first:
        search_symbol(driver, ticker)

    if internet_speed == 'fast':
        sleep_time = 2
    elif internet_speed == 'slow':
        sleep_time = 3
        time.sleep(1)
    # Find main iframe
    driver.switch_to.default_content()
    iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
    driver.switch_to.frame(iframes[3])

    # Switch to Valuation tab
    WebDriverWait(driver, 10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/nav/ul/li[6]/a')).click()
    #time.sleep(1)

    # Switch to First tab under Valuation (also Valuation)
    WebDriverWait(driver,10).until(lambda x: x.find_element(By.XPATH, '//*[@id="stock-valuationmodule"]/div/div[1]/nav/a[1]')).click()
    driver.switch_to.default_content()
    iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
    driver.switch_to.frame(iframes[3])

    # Wait for condition before advancing
    WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, '{} vs Industry'.format(ticker)))
    
    # Prepare to scrape valuation tabs by xpath
    tab_names = ['Valuation',
                 'Profitability',
                 'Dividend',
                 'Gowth rates',
                 'Effectiveness',
                 'Financial strength'
                ]
    xpaths = ['//*[@id="stock-valuationmodule"]/div/div[1]/nav/a[1]',
              '//*[@id="stock-valuationmodule"]/div/div[1]/nav/a[2]',
              '//*[@id="stock-valuationmodule"]/div/div[1]/nav/a[3]',
              '//*[@id="stock-valuationmodule"]/div/div[1]/nav/a[4]',
              '//*[@id="stock-valuationmodule"]/div/div[1]/nav/a[5]',
              '//*[@id="stock-valuationmodule"]/div/div[1]/nav/a[6]'
             ]
    tabs = dict(zip(tab_names, xpaths))

    # Scrape each tab
    valuation_df = pd.DataFrame()
    for name, xpath in tabs.items():
        # Switch to Appropriate Report
        driver.find_element(By.XPATH, xpath).click()
        iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
        driver.switch_to.frame(iframes[3])
        driver.switch_to.default_content()
        iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
        driver.switch_to.frame(iframes[3])
        WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, '{} vs Industry'.format(ticker)))
        element = WebDriverWait(driver, 10).until(lambda x: x.find_element(By.XPATH, '//*[@id="stock-valuationmodule"]/div/div[1]/div[2]'))
        WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, '{} Analysis'.format(name)))
        time.sleep(sleep_time)
        # Prevents breaking when there is no info on a tab, by waiting for condition
        try:
            element = driver.find_element(By.XPATH, '//*[@id="stock-valuationmodule"]/div/div/div[2]/table/tbody/tr[1]/td[2]')
            WebDriverWait(driver, 10).until(lambda x: EC.visibility_of_element_located(element))
        except:
            continue

        # Make soup and find container
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        contain = soup.find('div', {'data-module-name':'StocksValuationModule'})
        
        # Get data
        row_names = [x.get_text() for x in contain.find_all('a', {'class':'definition-link'})]
        tds = soup.find_all('td', {'class':'data-compare'})
        value_dict = {}
        for i, row_name in enumerate(row_names[1:]):
            value_dict[row_name] = {}
            dts = tds[i].find_all('dt')
            dds = tds[i].find_all('dd')
            cols = [dt.get_text() for dt in dts]
            vals = [dd.get_text() for dd in dds]
            value_dict[row_name][cols[0]] = vals[0]
            value_dict[row_name][cols[1]] = vals[1]
            value_dict[row_name]['Type'] = name

        # Create dataframe
        temp = pd.DataFrame.from_dict(value_dict, orient='columns').T
        valuation_df = pd.concat([valuation_df, temp], axis=0, sort=False)
    
    # Clean all columns except 'Type'
    for col in valuation_df.columns:
        if col != 'Type':
            valuation_df[col] = valuation_df[col].apply(lambda x: clean(x))

    # Create ratio to industry feature for normalized feature
    valuation_df['Ratio to Industry'] = valuation_df[ticker] / valuation_df['Industry']
    
    return valuation_df

def scrape_analysts(driver, ticker, search_first=True, internet_speed='fast'):
    """
    This function scrapes the "Analyst Reports" tab of a TD Ameritrade security
    lookup page
    :param driver: (Selenium webdriver) webdriver returned from start_bot()
    :param ticker: (str) ticker symbol to scrape
    :param search_first: (bool) allows for chain of scrapes to be done on one
                                security when set to False. Leave set to True
                                unless you are sure you are already on the
                                desired security, or the wrong data will scrape
    :param internet_speed: (str) set to 'slow' if bot is not working properly due
                                to slow page loading times.
    """
    # Search symbol first if flag is True
    if search_first:
        search_symbol(driver, ticker)

        if internet_speed == 'slow':
            time.sleep(1)

    if internet_speed == 'fast':
        sleep_time = 1
    elif internet_speed == 'slow':
        sleep_time = 2
    # Find iframe with tabs (main iframe)
    driver.switch_to.default_content()
    iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
    driver.switch_to.frame(iframes[3])

    # Switch to Analyst Reports tab
    WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Summary'))
    driver.find_element(By.XPATH, '//*[@id="layout-full"]/nav/ul/li[8]/a').click()
    time.sleep(sleep_time)

    # Wait for conditions before soup is made
    driver.switch_to.default_content()
    iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
    driver.switch_to.frame(iframes[3])
    WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Archived Reports'))

    # Make soup and find container and elements
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    contain = soup.find('table', {'class':'ui-table provider-table'}).find('tbody')
    trs = contain.find_all('tr')

    analysts = []
    ratings = []
    dates = []
    for tr in trs:
        divs = tr.find_all('div')
        analyst = divs[0].get('class')[1].strip()
        
        try:
            # Skip vickers
            if analyst == 'vickers':
                continue
            # Special treatment for marketEdge
            else:
                # Get date or NaN otherwise
                try:
                    txt = tr.find('p', {'class':'rating-since'}).get_text()
                    date = txt.replace('Rating Since ','')
                except:
                    date = np.NaN
                # Special treatment for marketEdge
                if analyst == 'marketEdge':
                    analysts.append(analyst+' opinion')
                    rating = divs[2].get('class')[2]
                    ratings.append(rating)
                    dates.append(date)
                    flag = False
                    i = 0
                    while flag == False:
                        i += 1
                        rating = divs[3].get('class')[1][-i].strip()
                        try:
                            rating = float(rating)
                            if i != 1:
                                rating = -rating
                            flag = True
                        except:
                            flag = False
                # Special treatment for cfra
                elif analyst == 'cfra':
                    rating = divs[2].get('class')[1][-1].strip()
                    try:
                        int(rating)
                    except:
                        rating = np.NaN
                else:
                    rating = divs[2].get('class')[1].strip()
                # Try to make ratings numeric
                try:
                    rating = int(rating)
                except:
                    rating = rating
        except:
            rating = np.NaN
            date = np.NaN

        analysts.append(analyst)
        ratings.append(rating)
        dates.append(date)

    # Create dataframe
    analyst_dict = dict(zip(analysts,zip(ratings,dates)))
    temp = pd.DataFrame.from_dict(analyst_dict, 
                                  orient='index', 
                                  columns=[ticker,'Rating Since'],
                                  )
    # Convert date column to datetime
    temp['Rating Since'] = pd.to_datetime(temp['Rating Since'], infer_datetime_format=True)
    
    return temp

def scrape_ticker(driver, ticker, errors='ignore', internet_speed='fast'):
    """
    This function scrapes every tab of a security based on ticker passed.
    Each scrape will be attempted 5 times before being skipped, as it is 
    unlikely for the data to fail to scrape this many times unless it is 
    truly absent.
    :param driver: (Selenium webdriver) webdriver returned from start_bot()
    :param ticker: (str) ticker symbol to scrape
    :param internet_speed: (str) set to 'slow' if bot is not working properly due
                                to slow page loading times.
    """
    # Getting Summary
    success = False
    tries = 0
    while not success:
        tries += 1
        try:
            summary = scrape_summary(driver, ticker, internet_speed=internet_speed)
            success = True
        except:
            print("Failed to gather summary for {} on attempt {}".format(ticker, tries))
        if tries >= 5:    
            print("Too many failed attempts for summary of {}, skipping to next df.".format(ticker))
            summary = pd.DataFrame(columns=[ticker])
            if errors == 'raise':
                raise
            elif errors == 'ignore':
                break

    # Getting Earnings
    success = False
    tries = 0
    while not success:
        tries += 1
        try:
            earnings, earnings_yearly = scrape_earnings(driver, ticker, search_first=False, internet_speed=internet_speed)
            success = True
        except:
            print("Failed to gather earnings for {} on attempt {}".format(ticker, tries))
        if tries >= 5:
            print("Too many failed attempts for earnings of {}, skipping to next df.".format(ticker))
            earnings = pd.DataFrame(columns=[ticker])
            earnings_yearly = pd.DataFrame(columns=[ticker])
            if errors == 'raise':
                raise
            elif errors == 'ignore':
                break
    
    # Getting fundamentals
    success = False
    tries = 0
    while not success:
        tries += 1
        try:
            fundies, fundies_yearly = scrape_fundamentals(driver, ticker, search_first=False, internet_speed=internet_speed)
            success = True
        except:
            print("Failed to gather fundamentals for {} on attempt {}".format(ticker, tries))
        if tries >= 5:
            print("Too many failed attempts for fundamentals of {}, skipping to next df.".format(ticker))
            fundies = pd.DataFrame(columns=[ticker])
            fundies_yearly = pd.DataFrame(columns=[ticker])
            if errors == 'raise':
                raise
            elif errors == 'ignore':
                break

    # Getting valuation
    success = False
    tries = 0
    while not success:
        tries += 1
        try:
            valuation = scrape_valuation(driver, ticker, search_first=False, internet_speed=internet_speed)
            success = True
        except:
            print("Failed to gather valuation for {} on attempt {}".format(ticker, tries))
        if tries >= 5:
            print("Too many failed attempts for valuation of {}, skipping to next df.".format(ticker))
            valuation = pd.DataFrame(columns=[ticker])
            if errors == 'raise':
                raise
            elif errors == 'ignore':
                break
    
    # Getting analyst reports
    success = False
    tries = 0
    while not success:
        tries += 1
        try:
            analysis = scrape_analysts(driver, ticker, search_first=False, internet_speed=internet_speed)
            success = True
        except:
            print("Failed to gather analysts for {} on attempt {}".format(ticker, tries))
        if tries >= 5:
            print("Too many failed attempts for analysts of {}, skipping to next df.".format(ticker))
            analysis = pd.DataFrame(columns=[ticker])
            if errors == 'raise':
                raise
            elif errors == 'ignore':
                break
    
    # Create combined 1D df for later stacking
    combined = pd.concat([summary[ticker].drop(index=['Shares Outstanding']),
                          earnings[ticker],
                          fundies[ticker],
                          valuation[ticker],
                          analysis[ticker]
                         ],
                        axis=0)
    # Remove duplicate rows from combined
    combined = pd.DataFrame(combined.loc[~combined.index.duplicated(keep='first')])
    for analyst in analysis.index:
        combined.loc[analyst+' since'] = analysis.loc[analyst, 'Rating Since']
    # Produce dictionary of results
    results = {'combined':combined, 
               'summary':summary, 
               'earnings':earnings, 
               'earnings_yearly':earnings_yearly, 
               'fundies':fundies, 
               'fundies_yearly':fundies_yearly, 
               'valuation':valuation,
               'analysts':analysis
              }
    return results

def scrape_watchlist(driver, tickers, name, root_dir='', skip_finished=True,
                     save_df=False, errors='ignore', return_skipped=False,
                     internet_speed='fast'):
    """
    Main wrapper function for scraper. Can do large lists of securities,
    and will store the data into assigned directory (can be set with kwarg)
    :param driver: selenium webdriver
    :param tickers: (list) ticker symbols
    :param name: (str) name of watchlist
    :param root_dir: (str) directory to save database to. Will use current working
                            directory if none passed.
    :param save_df: (bool) Whether to save the combined df to disk
    :param errors: (str) 'raise' or 'ignore'
    :param return_skipped: (bool) can return list of skipped securities if
                            ignoring errors
    :param internet_speed: (str) set to 'slow' if bot is not working properly due
                            to slow page loading times.
    """
    # Make list for skipped securities if needed
    if return_skipped == True:
        skipped = []

    # Create path name based on date and watchlist name, and make directory
    # path_name = root_dir + name + '_' + datetime.today().strftime('%m-%d-%Y')
    path_name = root_dir + name + '_' + datetime(2022, 11, 27).strftime('%m-%d-%Y')
    if not os.path.isdir(path_name):
        os.mkdir(path_name)
    
    # Create empty dataframe
    big_df = pd.DataFrame()
    
    # Scrape each ticker
    for i, ticker in enumerate(tickers):
        tickers_done = i + 1
        # Establish ticker path
        ticker_path = path_name+'/{}'.format(ticker)
        
        # Skip previously scraped securities if flag is True
        if skip_finished:
            if os.path.isdir(ticker_path):
                continue
        
        # Scrape security
        try:
            results = scrape_ticker(driver, ticker, errors=errors, internet_speed=internet_speed)
        except:
            print("Did not successfully scrape {}".format(ticker))
            if errors == 'raise':
                raise
            else:
                if return_skipped:
                    skipped.append(ticker)
                continue
        
        # Make directory if there is none
        if not os.path.isdir(ticker_path):
            os.mkdir(ticker_path)
        
        # Dump .csv files to directory
        for name, dataframe in results.items():
            try:
                dataframe.to_csv(ticker_path + '/{}'.format(name) + '.csv')
            except:
                print("No {} dataframe for {}".format(name,ticker))
        
        # Compile security to big_df
        big_df = pd.concat([big_df, results['combined'].T], axis=0, sort=True)
        
        # Print number of tickers completed every 10 completions
        if tickers_done % 10 == 0:
            print("{} tickers scraped".format(tickers_done))

    # Saves combined dataframe to file if called
    if save_df:
        big_df.to_csv(path_name + '/{}'.format('big_df.csv'))
    
    if not return_skipped:
        return big_df,
    else:
        return big_df, skipped

def build_big_df(tickers, database_path):
    """
    This function reads a previously scraped watchlist database at the provided
    path, and combines all of the 'combined.csv' files into one dataframe.
    :param tickers: (list-like) The securities to be gathered
    :param database_path: (str) The location of the database
    """
    big_df = pd.DataFrame()
    for ticker in tickers:
        file_path = database_path+'/{}/combined.csv'.format(ticker)
        try:
            temp = pd.read_csv(file_path, index_col='Unnamed: 0').T
        except:
            temp = pd.DataFrame(pd.read_csv(file_path)).T
        big_df = pd.concat([big_df, temp.astype('float64',errors='ignore')], axis=0, sort=True)
    new_df = pd.DataFrame()
    for col in big_df:
        new_df[col] = big_df[col].astype('float64', copy=True, errors='ignore')
    for col in new_df.columns:
        if col.endswith('since'):
            new_df[col] = pd.to_datetime(new_df[col], infer_datetime_format=True)
    
    return new_df

# %%
ticker_lists = pd.read_csv('nmr_us_tickers.csv')

# %%
driver = start_bot(get_keys('tda_keys.json'))

# %%
results = scrape_ticker(driver, 'NVDA', internet_speed='slow')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1707361144.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],

# %%
results.keys()
# Out:
# dict_keys(['combined', 'summary', 'earnings', 'earnings_yearly', 'fundies', 'fundies_yearly', 'valuation', 'analysts'])

# %%
df, skipped = scrape_watchlist(driver, ticker_lists.yahoo.tolist(), 'nmr_us', root_dir='', skip_finished=True, return_skipped=True, internet_speed='slow')
# Out:
# Failed to gather summary for BRKS on attempt 1
# Failed to gather summary for BRKS on attempt 2
# Failed to gather summary for BRKS on attempt 3
# Failed to gather summary for BRKS on attempt 4
# Failed to gather summary for BRKS on attempt 5
# Too many failed attempts for summary of BRKS, skipping to next df.
# Failed to gather earnings for BRKS on attempt 1
# Failed to gather earnings for BRKS on attempt 2
# Failed to gather earnings for BRKS on attempt 3
# Failed to gather earnings for BRKS on attempt 4
# Failed to gather earnings for BRKS on attempt 5
# Too many failed attempts for earnings of BRKS, skipping to next df.
# Failed to gather fundamentals for BRKS on attempt 1
# Failed to gather fundamentals for BRKS on attempt 2
# Failed to gather fundamentals for BRKS on attempt 3
# Failed to gather fundamentals for BRKS on attempt 4
# Failed to gather fundamentals for BRKS on attempt 5
# Too many failed attempts for fundamentals of BRKS, skipping to next df.
# Failed to gather valuation for BRKS on attempt 1
# Failed to gather valuation for BRKS on attempt 2
# Failed to gather valuation for BRKS on attempt 3
# Failed to gather valuation for BRKS on attempt 4
# Failed to gather valuation for BRKS on attempt 5
# Too many failed attempts for valuation of BRKS, skipping to next df.
# Failed to gather analysts for BRKS on attempt 1
# Failed to gather analysts for BRKS on attempt 2
# Failed to gather analysts for BRKS on attempt 3
# Failed to gather analysts for BRKS on attempt 4
# Failed to gather analysts for BRKS on attempt 5
# Too many failed attempts for analysts of BRKS, skipping to next df.
# Did not successfully scrape BRKS
# Failed to gather summary for BF-B on attempt 1
# Failed to gather summary for BF-B on attempt 2
# Failed to gather summary for BF-B on attempt 3
# Failed to gather summary for BF-B on attempt 4
# Failed to gather summary for BF-B on attempt 5
# Too many failed attempts for summary of BF-B, skipping to next df.
# Failed to gather earnings for BF-B on attempt 1
# Failed to gather earnings for BF-B on attempt 2
# Failed to gather earnings for BF-B on attempt 3
# Failed to gather earnings for BF-B on attempt 4
# Failed to gather earnings for BF-B on attempt 5
# Too many failed attempts for earnings of BF-B, skipping to next df.
# Failed to gather fundamentals for BF-B on attempt 1
# Failed to gather fundamentals for BF-B on attempt 2
# Failed to gather fundamentals for BF-B on attempt 3
# Failed to gather fundamentals for BF-B on attempt 4
# Failed to gather fundamentals for BF-B on attempt 5
# Too many failed attempts for fundamentals of BF-B, skipping to next df.
# Failed to gather valuation for BF-B on attempt 1
# Failed to gather valuation for BF-B on attempt 2
# Failed to gather valuation for BF-B on attempt 3
# Failed to gather valuation for BF-B on attempt 4
# Failed to gather valuation for BF-B on attempt 5
# Too many failed attempts for valuation of BF-B, skipping to next df.
# Failed to gather analysts for BF-B on attempt 1
# Failed to gather analysts for BF-B on attempt 2
# Failed to gather analysts for BF-B on attempt 3
# Failed to gather analysts for BF-B on attempt 4
# Failed to gather analysts for BF-B on attempt 5
# Too many failed attempts for analysts of BF-B, skipping to next df.
# Did not successfully scrape BF-B
# Failed to gather summary for BRK-B on attempt 1
# Failed to gather summary for BRK-B on attempt 2
# Failed to gather summary for BRK-B on attempt 3
# Failed to gather summary for BRK-B on attempt 4
# Failed to gather summary for BRK-B on attempt 5
# Too many failed attempts for summary of BRK-B, skipping to next df.
# Failed to gather earnings for BRK-B on attempt 1
# Failed to gather earnings for BRK-B on attempt 2
# Failed to gather earnings for BRK-B on attempt 3
# Failed to gather earnings for BRK-B on attempt 4
# Failed to gather earnings for BRK-B on attempt 5
# Too many failed attempts for earnings of BRK-B, skipping to next df.
# Failed to gather fundamentals for BRK-B on attempt 1
# Failed to gather fundamentals for BRK-B on attempt 2
# Failed to gather fundamentals for BRK-B on attempt 3
# Failed to gather fundamentals for BRK-B on attempt 4
# Failed to gather fundamentals for BRK-B on attempt 5
# Too many failed attempts for fundamentals of BRK-B, skipping to next df.
# Failed to gather valuation for BRK-B on attempt 1
# Failed to gather valuation for BRK-B on attempt 2
# Failed to gather valuation for BRK-B on attempt 3
# Failed to gather valuation for BRK-B on attempt 4
# Failed to gather valuation for BRK-B on attempt 5
# Too many failed attempts for valuation of BRK-B, skipping to next df.
# Failed to gather analysts for BRK-B on attempt 1
# Failed to gather analysts for BRK-B on attempt 2
# Failed to gather analysts for BRK-B on attempt 3
# Failed to gather analysts for BRK-B on attempt 4
# Failed to gather analysts for BRK-B on attempt 5
# Too many failed attempts for analysts of BRK-B, skipping to next df.
# Did not successfully scrape BRK-B
# Failed to gather summary for LGF-A on attempt 1
# Failed to gather summary for LGF-A on attempt 2
# Failed to gather summary for LGF-A on attempt 3
# Failed to gather summary for LGF-A on attempt 4
# Failed to gather summary for LGF-A on attempt 5
# Too many failed attempts for summary of LGF-A, skipping to next df.
# Failed to gather earnings for LGF-A on attempt 1
# Failed to gather earnings for LGF-A on attempt 2
# Failed to gather earnings for LGF-A on attempt 3
# Failed to gather earnings for LGF-A on attempt 4
# Failed to gather earnings for LGF-A on attempt 5
# Too many failed attempts for earnings of LGF-A, skipping to next df.
# Failed to gather fundamentals for LGF-A on attempt 1
# Failed to gather fundamentals for LGF-A on attempt 2
# Failed to gather fundamentals for LGF-A on attempt 3
# Failed to gather fundamentals for LGF-A on attempt 4
# Failed to gather fundamentals for LGF-A on attempt 5
# Too many failed attempts for fundamentals of LGF-A, skipping to next df.
# Failed to gather valuation for LGF-A on attempt 1
# Failed to gather valuation for LGF-A on attempt 2
# Failed to gather valuation for LGF-A on attempt 3
# Failed to gather valuation for LGF-A on attempt 4
# Failed to gather valuation for LGF-A on attempt 5
# Too many failed attempts for valuation of LGF-A, skipping to next df.
# Failed to gather analysts for LGF-A on attempt 1
# Failed to gather analysts for LGF-A on attempt 2
# Failed to gather analysts for LGF-A on attempt 3
# Failed to gather analysts for LGF-A on attempt 4
# Failed to gather analysts for LGF-A on attempt 5
# Too many failed attempts for analysts of LGF-A, skipping to next df.
# Did not successfully scrape LGF-A
# Failed to gather summary for MOG-A on attempt 1
# Failed to gather summary for MOG-A on attempt 2
# Failed to gather summary for MOG-A on attempt 3
# Failed to gather summary for MOG-A on attempt 4
# Failed to gather summary for MOG-A on attempt 5
# Too many failed attempts for summary of MOG-A, skipping to next df.
# Failed to gather earnings for MOG-A on attempt 1
# Failed to gather earnings for MOG-A on attempt 2
# Failed to gather earnings for MOG-A on attempt 3
# Failed to gather earnings for MOG-A on attempt 4
# Failed to gather earnings for MOG-A on attempt 5
# Too many failed attempts for earnings of MOG-A, skipping to next df.
# Failed to gather fundamentals for MOG-A on attempt 1
# Failed to gather fundamentals for MOG-A on attempt 2
# Failed to gather fundamentals for MOG-A on attempt 3
# Failed to gather fundamentals for MOG-A on attempt 4
# Failed to gather fundamentals for MOG-A on attempt 5
# Too many failed attempts for fundamentals of MOG-A, skipping to next df.
# Failed to gather valuation for MOG-A on attempt 1
# Failed to gather valuation for MOG-A on attempt 2
# Failed to gather valuation for MOG-A on attempt 3
# Failed to gather valuation for MOG-A on attempt 4
# Failed to gather valuation for MOG-A on attempt 5
# Too many failed attempts for valuation of MOG-A, skipping to next df.
# Failed to gather analysts for MOG-A on attempt 1
# Failed to gather analysts for MOG-A on attempt 2
# Failed to gather analysts for MOG-A on attempt 3
# Failed to gather analysts for MOG-A on attempt 4
# Failed to gather analysts for MOG-A on attempt 5
# Too many failed attempts for analysts of MOG-A, skipping to next df.
# Did not successfully scrape MOG-A
# Failed to gather summary for OMI on attempt 1
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Failed to gather summary for OMI on attempt 2
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Failed to gather summary for OMI on attempt 3
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Failed to gather summary for OMI on attempt 4
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Failed to gather summary for OMI on attempt 5
# Too many failed attempts for summary of OMI, skipping to next df.
# Did not successfully scrape OMI
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# 2170 tickers scraped
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Failed to gather earnings for WTRG on attempt 1
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# 2180 tickers scraped
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Historic Growth not available for XMTR
# ...
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Historic Growth not available for ZNTL
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# 2210 tickers scraped
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Failed to gather fundamentals for ZTS on attempt 1
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# Historic Growth not available for ZWS
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:314: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_7664\2121936164.py:318: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],

# %%
skipped.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Quant_projects\experiments.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Quant_projects/experiments.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> skipped.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
skipped
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Quant_projects\experiments.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Quant_projects/experiments.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> skipped
#
# NameError: name 'skipped' is not defined

# %%
df
# Out:
#      % Above Low % Below High % Held by Institutions        52-Wk Range  \
# WTFC      0.1549          NaN                 0.9153   [76.13 - 105.56]
# WTRG         NaN       0.1161                  0.767    [38.50 - 53.93]
# WTS       0.3075          NaN                 0.9541  [116.31 - 201.00]
# WTTR         NaN       0.2272                 0.6313     [5.54 - 10.43]
# WTW          NaN       0.0211                 0.9551  [187.89 - 244.73]
# WU        0.1627          NaN                 1.0081    [12.27 - 20.40]
# WW        0.1287          NaN                 0.8176     [3.42 - 19.07]
# WWD       0.1927          NaN                 0.8323   [79.26 - 129.12]
# WWE          NaN       0.0102                  1.168    [46.91 - 81.63]
# WWW       0.0549          NaN                 0.9872    [10.39 - 33.41]
# WYNN         NaN       0.1896                 0.5799    [50.20 - 96.50]
# X         0.5527          NaN                 0.7454    [16.41 - 39.25]
# XEL          NaN       0.1065                 0.7596    [56.89 - 77.66]
# XMTR       0.546          NaN                 0.9398    [26.61 - 64.35]
# XNCR      0.4554          NaN                 1.0337    [19.36 - 42.30]
# XOM          NaN       0.0423                 0.5789   [57.96 - 114.66]
# XPEL         NaN        0.232                 0.6033    [39.80 - 87.01]
# XPO          NaN       0.2348                 0.9098    [24.75 - 48.13]
# XPOF         NaN       0.2011                 0.8526    [11.20 - 26.90]
# XPRO         NaN        0.127                 0.8255     [8.83 - 19.68]
# XRAY      0.1503          NaN                  0.985    [26.48 - 58.70]
# XRX       0.3093          NaN                 0.8144    [11.80 - 24.14]
# XXII      0.3176          NaN                 0.2102      [0.85 - 3.52]
# XYL          NaN       0.1258                  0.891   [72.08 - 125.38]
# YELP      0.1115          NaN                 0.9406    [26.28 - 39.27]
# YETI      0.4806          NaN                 0.9455    [27.86 - 98.58]
# YEXT       0.355          NaN                 0.6658     [4.00 - 10.97]
# YMAB      0.4218          NaN                 0.6382     [2.94 - 20.48]
# YOU          NaN       0.1223                 0.9947    [18.79 - 35.08]
# YUM          NaN       0.0958                  0.783  [103.97 - 139.85]
# ZBH       0.1721          NaN                 0.9067  [100.39 - 135.05]
# ZBRA      0.1963          NaN                 0.8898  [224.87 - 615.00]
# JCOM      0.3292          NaN                 1.0261   [66.85 - 115.84]
# ZETA      1.0709          NaN                 0.5741     [4.09 - 13.46]
# ZG        0.3272          NaN                 0.8398    [26.21 - 65.16]
# ZI        0.1692          NaN                 0.8889    [23.29 - 71.50]
# ZION      0.0784          NaN                 0.8401    [46.58 - 75.44]
# ZIP        0.246          NaN                 0.9181    [13.78 - 30.49]
# ZM        0.0164          NaN                 0.6125   [70.44 - 221.41]
# ZNTL      0.1916          NaN                 1.0313    [17.33 - 85.95]
# ZS        0.1971          NaN                 0.4781  [114.21 - 373.74]
# ZTS       0.1932          NaN                 0.9115  [124.15 - 249.27]
# ZUMZ      0.1557          NaN                 0.8994    [20.29 - 49.98]
# ZUO       0.2225          NaN                 0.7442     [6.14 - 20.43]
# ZWS       0.1131          NaN                 0.7604    [21.39 - 37.77]
# ZYXI         NaN       0.0715                  0.285     [4.97 - 14.55]
#
#      5yr Avg Return 5yr High 5yr Low Annual Dividend $ Annual Dividend %  \
# WTFC       0.020683   105.56   22.02              1.36            0.0151
# WTRG       0.055567    54.52    30.4              1.15            0.0236
# WTS         0.17145    212.0   61.17               1.2            0.0077
# WTTR       0.034317    21.96    2.22               0.2            0.0249
# WTW        0.072867   271.87   134.5              3.28            0.0134
# WU        -0.021783    28.45   12.27              0.94            0.0658
# WW          -0.2673   105.73    3.42               NaN               NaN
# WWD         0.06155   130.75   46.51              0.76            0.0077
# WWE         0.29585   100.45   27.81              0.48            0.0059
# WWW        -0.10525    44.74   10.39               0.4            0.0356
# WYNN          -0.07   203.63   35.84               NaN               NaN
# X          0.043883    47.64    4.54               0.2            0.0077
# XEL         0.05705    77.66   41.51              1.95             0.028
# XMTR        -0.2311    97.57   26.61               NaN               NaN
# XNCR       0.089183    58.35   19.35               NaN               NaN
# XOM        0.120017   114.66   30.11              3.64            0.0322
# XPEL       1.237133   103.84    1.32               NaN               NaN
# XPO        -0.02735   153.45   30.54               NaN               NaN
# XPOF        0.43035     26.9    9.87               NaN               NaN
# XPRO      -0.093767     58.5    8.83               NaN               NaN
# XRAY      -0.069567    69.54   26.48               0.5            0.0159
# XRX       -0.029067    39.47    11.8               1.0            0.0629
# XXII       0.043817     6.07    0.55               NaN               NaN
# XYL        0.091717   138.78   54.62               1.2            0.0106
# YELP      -0.062767     52.5   12.89               NaN               NaN
# YETI         0.3785   108.82    12.4               NaN               NaN
# YEXT      -0.107583    27.19     4.0               NaN               NaN
# YMAB       -0.10356    55.22    2.94               NaN               NaN
# YOU        -0.10475     65.7   18.79               NaN               NaN
# YUM        0.080417   139.85   54.95              2.28             0.018
# ZBH        0.018817   180.36   74.37              0.96            0.0081
# ZBRA         0.2652    615.0  101.49               NaN               NaN
# JCOM       0.034233   147.35   53.25               NaN               NaN
# ZETA       -0.03215    13.46    4.09               NaN               NaN
# ZG         0.203733    212.4   18.65               NaN               NaN
# ZI        -0.012067    79.17   23.29               NaN               NaN
# ZION        0.02965    75.44   23.58              1.64            0.0317
# ZIP        -0.03445     32.9   13.78               NaN               NaN
# ZM         0.719525   588.84   59.94               NaN               NaN
# ZNTL          0.298    87.19   17.33               NaN               NaN
# ZS          0.78614   376.11   24.76               NaN               NaN
# ZTS        0.180483   249.27    70.2               1.3            0.0087
# ZUMZ       0.086967     55.1   13.13               NaN               NaN
# ZUO        -0.11292    37.78    6.14               NaN               NaN
# ZWS        0.023633    65.68   18.87              0.28            0.0113
# ZYXI       0.438817    27.02    1.68               NaN               NaN
#
#      Annual Dividend Yield  ...  marketEdge marketEdge opinion  \
# WTFC                0.0151  ...         NaN                NaN
# WTRG                0.0236  ...         NaN                NaN
# WTS                 0.0077  ...         NaN                NaN
# WTTR                0.0249  ...         NaN                NaN
# WTW                 0.0134  ...         NaN                NaN
# WU                  0.0658  ...         NaN                NaN
# WW                     NaN  ...         NaN                NaN
# WWD                 0.0077  ...         NaN                NaN
# WWE                 0.0059  ...         NaN                NaN
# WWW                 0.0356  ...         NaN                NaN
# WYNN                   NaN  ...         NaN                NaN
# X                   0.0077  ...         NaN                NaN
# XEL                  0.028  ...         NaN                NaN
# XMTR                   NaN  ...         NaN                NaN
# XNCR                   NaN  ...         NaN                NaN
# XOM                 0.0322  ...         NaN                NaN
# XPEL                   NaN  ...         NaN                NaN
# XPO                    NaN  ...         NaN                NaN
# XPOF                   NaN  ...         NaN                NaN
# XPRO                   NaN  ...         NaN                NaN
# XRAY                0.0159  ...         NaN                NaN
# XRX                 0.0629  ...         NaN                NaN
# XXII                   NaN  ...         NaN                NaN
# XYL                 0.0106  ...         NaN                NaN
# YELP                   NaN  ...         NaN                NaN
# YETI                   NaN  ...         NaN                NaN
# YEXT                   NaN  ...         NaN                NaN
# YMAB                   NaN  ...         NaN                NaN
# YOU                    NaN  ...         NaN                NaN
# YUM                  0.018  ...         NaN                NaN
# ZBH                 0.0082  ...         NaN                NaN
# ZBRA                   NaN  ...         NaN                NaN
# JCOM                   NaN  ...         NaN                NaN
# ZETA                   NaN  ...         NaN                NaN
# ZG                     NaN  ...  rating-box                NaN
# ZI                     NaN  ...         NaN                NaN
# ZION                0.0326  ...         NaN                NaN
# ZIP                    NaN  ...         NaN                NaN
# ZM                     NaN  ...         NaN                NaN
# ZNTL                   NaN  ...         NaN                NaN
# ZS                     NaN  ...         NaN                NaN
# ZTS                 0.0088  ...         NaN                NaN
# ZUMZ                   NaN  ...         NaN                NaN
# ZUO                    NaN  ...  rating-box                NaN
# ZWS                 0.0118  ...         NaN                NaN
# ZYXI                   NaN  ...         NaN                NaN
#
#      marketEdge opinion since marketEdge since newConstructs  \
# WTFC                      NaT              NaT    rating-box
# WTRG                      NaT              NaT    rating-box
# WTS                       NaT              NaT    rating-box
# WTTR                      NaT              NaT    rating-box
# WTW                       NaT              NaT    rating-box
# WU                        NaT              NaT    rating-box
# WW                        NaT              NaT    rating-box
# WWD                       NaT              NaT    rating-box
# WWE                       NaT              NaT    rating-box
# WWW                       NaT              NaT    rating-box
# WYNN                      NaT              NaT    rating-box
# X                         NaT              NaT    rating-box
# XEL                       NaT              NaT    rating-box
# XMTR                      NaT              NaT    rating-box
# XNCR                      NaT              NaT    rating-box
# XOM                       NaT              NaT    rating-box
# XPEL                      NaT              NaT    rating-box
# XPO                       NaT              NaT    rating-box
# XPOF                      NaT              NaT    rating-box
# XPRO                      NaT              NaT    rating-box
# XRAY                      NaT              NaT    rating-box
# XRX                       NaT              NaT    rating-box
# XXII                      NaT              NaT    rating-box
# XYL                       NaT              NaT    rating-box
# YELP                      NaT              NaT    rating-box
# YETI                      NaT              NaT    rating-box
# YEXT                      NaT              NaT    rating-box
# YMAB                      NaT              NaT    rating-box
# YOU                       NaT              NaT    rating-box
# YUM                       NaT              NaT    rating-box
# ZBH                       NaT              NaT    rating-box
# ZBRA                      NaT              NaT    rating-box
# JCOM                      NaT              NaT    rating-box
# ZETA                      NaT              NaT    rating-box
# ZG                        NaT       2021-12-03    rating-box
# ZI                        NaT              NaT    rating-box
# ZION                      NaT              NaT    rating-box
# ZIP                       NaT              NaT    rating-box
# ZM                        NaT              NaT    rating-box
# ZNTL                      NaT              NaT    rating-box
# ZS                        NaT              NaT    rating-box
# ZTS                       NaT              NaT    rating-box
# ZUMZ                      NaT              NaT    rating-box
# ZUO                       NaT              NaT           NaN
# ZWS                       NaT              NaT    rating-box
# ZYXI                      NaT              NaT    rating-box
#
#      newConstructs since researchTeam researchTeam since   theStreet  \
# WTFC          2022-11-28   rating-box         2022-10-21  rating-box
# WTRG          2022-11-28   rating-box         2022-02-18  rating-box
# WTS           2022-11-26   rating-box         2021-04-26  rating-box
# WTTR          2022-11-26   rating-box         2022-11-04  rating-box
# WTW           2022-11-26   rating-box         2022-08-20  rating-box
# WU            2022-11-28   rating-box         2022-08-20  rating-box
# WW            2022-11-28   rating-box         2022-10-30  rating-box
# WWD           2022-11-28   rating-box         2022-08-20  rating-box
# WWE           2022-11-28   rating-box         2022-11-25  rating-box
# WWW           2022-11-28   rating-box         2021-08-06  rating-box
# WYNN          2022-11-28   rating-box         2019-11-08  rating-box
# X             2022-11-28   rating-box         2021-08-06  rating-box
# XEL           2022-11-28   rating-box         2022-04-28  rating-box
# XMTR                 NaT   rating-box         2022-08-11  rating-box
# XNCR          2022-11-26   rating-box         2022-06-17  rating-box
# XOM           2022-11-28   rating-box         2022-08-20  rating-box
# XPEL          2022-11-28   rating-box         2022-09-30  rating-box
# XPO           2022-11-26   rating-box         2022-08-20  rating-box
# XPOF                 NaT   rating-box         2022-11-25  rating-box
# XPRO                 NaT   rating-box                NaT  rating-box
# XRAY          2022-11-26   rating-box         2022-11-15  rating-box
# XRX           2022-11-26   rating-box         2021-08-20  rating-box
# XXII                 NaT   rating-box                NaT  rating-box
# XYL           2022-11-28   rating-box         2021-03-29  rating-box
# YELP          2022-11-28   rating-box         2021-02-12  rating-box
# YETI          2022-11-28   rating-box         2021-12-23  rating-box
# YEXT          2022-11-28   rating-box         2018-06-01  rating-box
# YMAB                 NaT   rating-box                NaT  rating-box
# YOU                  NaT   rating-box         2022-08-16  rating-box
# YUM           2022-11-26   rating-box         2022-06-10  rating-box
# ZBH           2022-11-26   rating-box         2020-09-19  rating-box
# ZBRA          2022-11-26   rating-box         2021-07-05  rating-box
# JCOM          2022-11-26   rating-box         2021-08-06  rating-box
# ZETA                 NaT   rating-box         2022-08-04  rating-box
# ZG            2022-11-28   rating-box         2021-08-06  rating-box
# ZI            2022-11-28   rating-box         2022-07-29  rating-box
# ZION          2022-11-28   rating-box         2021-08-13  rating-box
# ZIP                  NaT   rating-box         2022-08-16  rating-box
# ZM            2022-11-26   rating-box         2022-04-19  rating-box
# ZNTL                 NaT   rating-box                NaT  rating-box
# ZS            2022-11-26   rating-box         2022-01-07  rating-box
# ZTS           2022-11-26   rating-box         2021-03-29  rating-box
# ZUMZ          2022-11-26   rating-box         2022-08-20  rating-box
# ZUO                  NaT   rating-box         2019-05-31  rating-box
# ZWS                  NaT   rating-box         2021-07-23  rating-box
# ZYXI          2022-11-28   rating-box         2022-07-29  rating-box
#
#      theStreet since
# WTFC      2021-05-11
# WTRG      2020-12-27
# WTS       2018-05-04
# WTTR      2022-11-04
# WTW       2021-12-27
# WU        2022-07-13
# WW        2022-10-30
# WWD       2022-02-01
# WWE       2022-05-17
# WWW       2021-06-25
# WYNN      2020-05-13
# X         2021-02-01
# XEL       2021-04-27
# XMTR      2022-08-11
# XNCR      2022-02-24
# XOM       2022-01-20
# XPEL      2022-08-18
# XPO       2022-05-10
# XPOF      2022-11-25
# XPRO             NaT
# XRAY      2022-11-15
# XRX       2022-07-08
# XXII      2019-04-01
# XYL       2022-11-02
# YELP      2022-11-02
# YETI      2022-05-06
# YEXT      2018-06-01
# YMAB      2022-03-28
# YOU       2022-08-16
# YUM       2021-07-30
# ZBH       2021-03-30
# ZBRA      2022-06-28
# JCOM      2022-06-07
# ZETA      2022-08-04
# ZG               NaT
# ZI        2022-05-20
# ZION      2020-11-17
# ZIP       2022-08-16
# ZM        2022-04-19
# ZNTL             NaT
# ZS        2022-01-07
# ZTS       2015-12-07
# ZUMZ      2022-06-06
# ZUO       2019-05-31
# ZWS       2021-05-20
# ZYXI      2021-12-21
#
# [46 rows x 99 columns]

# %%
ticker_lists
# Out:
#      yahoo
# 0        A
# 1       AA
# 2     AADI
# 3      AAL
# 4      AAN
# ...    ...
# 2210   ZTS
# 2211  ZUMZ
# 2212   ZUO
# 2213   ZWS
# 2214  ZYXI
#
# [2215 rows x 1 columns]

# %%
ticker_lists['yahoo']
# Out:
# 0          A
# 1         AA
# 2       AADI
# 3        AAL
# 4        AAN
#         ...
# 2210     ZTS
# 2211    ZUMZ
# 2212     ZUO
# 2213     ZWS
# 2214    ZYXI
# Name: yahoo, Length: 2215, dtype: object

# %%
skipped = ['BRKS', 'BF-B', 'BRK-B', 'LGF-A', 'MOG-A', 'OMI']

# %%
ticker_lists.loc[ticker_lists.yahoo.isin(skipped)]
# Out:
#       yahoo
# 232    BRKS
# 263    BF-B
# 321   BRK-B
# 1167  LGF-A
# 1292  MOG-A
# 1459    OMI

# %%
dir_path = 'nmr_us_11-27-2022'

# %%
ticker_lists_no_skipped = ticker_lists.loc[~ticker_lists.yahoo.isin(skipped)]

# %%
ticker_lists_no_skipped.reset_index(drop=True).to_csv('nmr_us_tickers_11-27-2022.csv', index=False)

# %%
nmr_us = build_big_df(ticker_lists_no_skipped.yahoo, dir_path)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19736\1961211346.py:1216: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_df[col] = big_df[col].astype('float64', copy=True, errors='ignore')
# C:\Users\USER\AppData\Local\Temp\ipykernel_19736\1961211346.py:1216: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_df[col] = big_df[col].astype('float64', copy=True, errors='ignore')
# C:\Users\USER\AppData\Local\Temp\ipykernel_19736\1961211346.py:1216: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_df[col] = big_df[col].astype('float64', copy=True, errors='ignore')
# C:\Users\USER\AppData\Local\Temp\ipykernel_19736\1961211346.py:1216: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_df[col] = big_df[col].astype('float64', copy=True, errors='ignore')

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 100)

# %%
nmr_us.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2209 entries, A to ZYXI
# Data columns (total 104 columns):
#  #    Column                                             Non-Null Count  Dtype
# ---   ------                                             --------------  -----
#  0    % Above Low                                        1297 non-null   float64
#  1    % Below High                                       912 non-null    float64
#  2    % Held by Institutions                             2198 non-null   float64
#  3    52-Wk Range                                        2209 non-null   object
#  4    5yr Avg Return                                     2190 non-null   float64
#  5    5yr High                                           2190 non-null   float64
#  6    5yr Low                                            2190 non-null   float64
#  7    Annual Dividend $                                  997 non-null    float64
#  8    Annual Dividend %                                  997 non-null    float64
#  9    Annual Dividend Yield                              984 non-null    float64
#  10   Ask                                                2105 non-null   float64
#  11   Ask Size                                           2043 non-null   float64
#  12   Ask close                                          115 non-null    float64
#  13   B/A Ratio                                          2043 non-null   float64
#  14   B/A Size                                           2209 non-null   object
#  15   Beta                                               1857 non-null   float64
#  16   Bid                                                2099 non-null   float64
#  17   Bid Size                                           2043 non-null   float64
#  18   Bid close                                          115 non-null    float64
#  19   Change Since Close                                 248 non-null    object
#  20   Change in Debt/Total Capital Quarter over Quarter  1839 non-null   float64
#  21   Closing Price                                      1770 non-null   float64
#  22   Day Change $                                       1866 non-null   float64
#  23   Day Change %                                       1866 non-null   float64
#  24   Day High                                           1866 non-null   float64
#  25   Day Low                                            1866 non-null   float64
#  26   Days to Cover                                      2179 non-null   float64
#  27   Dividend Change %                                  842 non-null    float64
#  28   Dividend Growth 5yr                                766 non-null    float64
#  29   Dividend Growth Rate, 3 Years                      812 non-null    float64
#  30   Dividend Pay Date                                  2209 non-null   object
#  31   EPS (TTM, GAAP)                                    2193 non-null   float64
#  32   EPS Growth (MRQ)                                   2165 non-null   float64
#  33   EPS Growth (TTM)                                   2111 non-null   float64
#  34   EPS Growth 5yr                                     1180 non-null   float64
#  35   Ex-dividend                                        997 non-null    object
#  36   Ex-dividend Date                                   2209 non-null   object
#  37   FCF Growth 5yr                                     2111 non-null   float64
#  38   Float                                              2178 non-null   float64
#  39   Gross Profit Margin (TTM)                          1748 non-null   float64
#  40   Growth 1yr Consensus Est                           1687 non-null   float64
#  41   Growth 1yr High Est                                1687 non-null   float64
#  42   Growth 1yr Low Est                                 1687 non-null   float64
#  43   Growth 2yr Consensus Est                           2185 non-null   float64
#  44   Growth 2yr High Est                                2185 non-null   float64
#  45   Growth 2yr Low Est                                 2185 non-null   float64
#  46   Growth 3yr Historic                                2186 non-null   float64
#  47   Growth 5yr Actual/Est                              2186 non-null   float64
#  48   Growth 5yr Consensus Est                           2185 non-null   float64
#  49   Growth 5yr High Est                                2185 non-null   float64
#  50   Growth 5yr Low Est                                 2185 non-null   float64
#  51   Growth Analysts                                    2184 non-null   float64
#  52   Historical Volatility                              2209 non-null   float64
#  53   Institutions Holding Shares                        2179 non-null   float64
#  54   Interest Coverage (MRQ)                            1462 non-null   float64
#  55   Last (size)                                        2209 non-null   float64
#  56   Last (time)                                        2209 non-null   object
#  57   Last Trade                                         248 non-null    float64
#  58   Market Cap                                         2209 non-null   object
#  59   Market Edge Opinion:                               1408 non-null   object
#  60   Net Profit Margin (TTM)                            2111 non-null   float64
#  61   Next Earnings Announcement                         2182 non-null   object
#  62   Operating Profit Margin (TTM)                      2105 non-null   float64
#  63   P/E Ratio (TTM, GAAP)                              1520 non-null   object
#  64   PEG Ratio (TTM, GAAP)                              602 non-null    float64
#  65   Prev Close                                         2209 non-null   float64
#  66   Price                                              439 non-null    float64
#  67   Price/Book (MRQ)                                   2067 non-null   float64
#  68   Price/Cash Flow (TTM)                              1623 non-null   float64
#  69   Price/Earnings (TTM)                               1502 non-null   float64
#  70   Price/Earnings (TTM, GAAP)                         1490 non-null   float64
#  71   Price/Sales (TTM)                                  2132 non-null   float64
#  72   Quick Ratio (MRQ)                                  1247 non-null   float64
#  73   Return On Assets (TTM)                             2156 non-null   float64
#  74   Return On Equity (TTM)                             2049 non-null   float64
#  75   Return On Investment (TTM)                         1936 non-null   float64
#  76   Revenue Growth (MRQ)                               2104 non-null   float64
#  77   Revenue Growth (TTM)                               2054 non-null   float64
#  78   Revenue Growth 5yr                                 1764 non-null   float64
#  79   Revenue Per Employee (TTM)                         1971 non-null   float64
#  80   Shares Outstanding                                 2179 non-null   float64
#  81   Short Int Current Month                            2179 non-null   float64
#  82   Short Int Pct of Float                             2179 non-null   float64
#  83   Short Int Prev Month                               2179 non-null   float64
#  84   Short Interest                                     2198 non-null   float64
#  85   Today's Open                                       1866 non-null   float64
#  86   Total Debt/Total Capital (MRQ)                     1992 non-null   float64
#  87   Volume                                             1770 non-null   float64
#  88   Volume 10-day Avg                                  1770 non-null   float64
#  89   Volume Past Day                                    2209 non-null   object
#  90   cfra                                               5 non-null      object
#  91   cfra since                                         755 non-null    datetime64[ns]
#  92   ford                                               2187 non-null   object
#  93   ford since                                         2101 non-null   datetime64[ns]
#  94   marketEdge                                         484 non-null    object
#  95   marketEdge opinion                                 0 non-null      float64
#  96   marketEdge opinion since                           0 non-null      datetime64[ns]
#  97   marketEdge since                                   432 non-null    datetime64[ns]
#  98   newConstructs                                      2155 non-null   object
#  99   newConstructs since                                1706 non-null   datetime64[ns]
#  100  researchTeam                                       2198 non-null   object
#  101  researchTeam since                                 1998 non-null   datetime64[ns]
#  102  theStreet                                          1795 non-null   object
#  103  theStreet since                                    1631 non-null   datetime64[ns]
# dtypes: datetime64[ns](7), float64(79), object(18)
# memory usage: 1.8+ MB

# %%
nmr_us.select_dtypes(include='object').columns
# Out:
# Index(['52-Wk Range', 'B/A Size', 'Change Since Close', 'Dividend Pay Date',
#        'Ex-dividend', 'Ex-dividend Date', 'Last (time)', 'Market Cap',
#        'Market Edge Opinion:', 'Next Earnings Announcement',
#        'P/E Ratio (TTM, GAAP)', 'Volume Past Day', 'cfra', 'ford',
#        'marketEdge', 'newConstructs', 'researchTeam', 'theStreet'],
#       dtype='object')

# %%
nmr_us['Volume Past Day'].value_counts()
# Out:
# (Light)            1898
# (Average)           111
# (Below Average)      90
# (Heavy Day)          84
# (Above Average)      26
# Name: Volume Past Day, dtype: int64

# %%
nmr_us['52-Wk Range'].head()
# Out:
# A       ['112.52 - 162.62']
# AA        ['33.55 - 98.09']
# AADI      ['11.00 - 26.60']
# AAL       ['11.65 - 21.42']
# AAN        ['7.65 - 25.96']
# Name: 52-Wk Range, dtype: object

# %%
nmr_us['52-Wk Range'].map(lambda x: x.strip("[]'").replace(' ', '').split('-'))
# Out:
# A       [112.52, 162.62]
# AA        [33.55, 98.09]
# AADI      [11.00, 26.60]
# AAL       [11.65, 21.42]
# AAN        [7.65, 25.96]
#               ...
# ZTS     [124.15, 249.27]
# ZUMZ      [20.29, 49.98]
# ZUO        [6.14, 20.43]
# ZWS       [21.39, 37.77]
# ZYXI       [4.97, 14.55]
# Name: 52-Wk Range, Length: 2209, dtype: object

# %%
nmr_us[nmr_us['Market Cap'].map(lambda x: 'T' in x)]
# Out:
#        % Above Low  % Below High  % Held by Institutions          52-Wk Range  \
# AAPL        0.1478           NaN                  0.5798  ['129.04 - 182.94']
# GOOGL       0.1694           NaN                  0.7615   ['83.34 - 151.55']
# MSFT        0.1596           NaN                  0.7009  ['213.43 - 344.30']
#
#        5yr Avg Return  5yr High  5yr Low  Annual Dividend $  \
# AAPL         0.290700    182.94    35.50               0.92
# GOOGL        0.151883    151.55    48.88                NaN
# MSFT         0.237217    349.67    80.70               2.72
#
#        Annual Dividend %  Annual Dividend Yield     Ask  Ask Size  Ask close  \
# AAPL              0.0062                 0.0062  148.12     800.0        NaN
# GOOGL                NaN                    NaN   97.37     400.0        NaN
# MSFT              0.0110                 0.0110  245.79     100.0     262.85
#
#        B/A Ratio  B/A Size  Beta     Bid  Bid Size  Bid close  \
# AAPL       5.875  4700x800   1.2  148.11    4700.0        NaN
# GOOGL      0.500   200x400   1.1   97.33     200.0        NaN
# MSFT       1.000   100x100   0.9  245.51     100.0     247.43
#
#       Change Since Close  Change in Debt/Total Capital Quarter over Quarter  \
# AAPL                 NaN                                            -0.0005
# GOOGL                NaN                                             0.0001
# MSFT    -1.84| |(-0.74%)                                            -0.0012
#
#        Closing Price  Day Change $  Day Change %  Day High  Day Low  \
# AAPL          148.11         -2.96       -0.0196    148.88   147.12
# GOOGL          97.46         -1.00       -0.0102     98.64    97.40
# MSFT          247.49           NaN           NaN       NaN      NaN
#
#        Days to Cover  Dividend Change %  Dividend Growth 5yr  \
# AAPL         1.21464             0.0588             0.084472
# GOOGL        1.24539                NaN                  NaN
# MSFT         1.01466             0.1050             0.096036
#
#        Dividend Growth Rate, 3 Years    Dividend Pay Date  EPS (TTM, GAAP)  \
# AAPL                          0.0627  2022-11-10 00:00:00             6.10
# GOOGL                            NaN          No dividend             4.94
# MSFT                          0.1037  2022-12-08 00:00:00             9.28
#
#        EPS Growth (MRQ)  EPS Growth (TTM)  EPS Growth 5yr  \
# AAPL             0.0753            0.0883        0.215750
# GOOGL           -0.1213           -0.0353        0.321133
# MSFT             0.0514            0.0374        0.242745
#
#                Ex-dividend Ex-dividend Date  FCF Growth 5yr     Float  \
# AAPL   2022-11-04 00:00:00         11/04/22        0.369541  15896.63
# GOOGL                  NaN      No dividend        0.208875  11592.08
# MSFT   2022-11-16 00:00:00         11/16/22        0.122475   7449.03
#
#        Gross Profit Margin (TTM)  Growth 1yr Consensus Est  \
# AAPL                      0.4331                  0.028248
# GOOGL                     0.5610                 -0.957107
# MSFT                      0.6826                  0.031239
#
#        Growth 1yr High Est  Growth 1yr Low Est  Growth 2yr Consensus Est  \
# AAPL              0.092210           -0.035714                  0.060196
# GOOGL            -0.957027           -0.957187                 -0.457131
# MSFT              0.058140            0.004338                  0.108625
#
#        Growth 2yr High Est  Growth 2yr Low Est  Growth 3yr Historic  \
# AAPL              0.081767            0.038624             0.199873
# GOOGL            -0.363759           -0.550504             0.276433
# MSFT              0.152446            0.064804             0.135417
#
#        Growth 5yr Actual/Est  Growth 5yr Consensus Est  Growth 5yr High Est  \
# AAPL                0.228001                  0.226432             0.236640
# GOOGL               0.264844                 -0.457131            -0.363759
# MSFT                0.187316                  0.194917             0.215847
#
#        Growth 5yr Low Est  Growth Analysts  Historical Volatility  \
# AAPL             0.216224             39.0                  0.355
# GOOGL           -0.550504             42.0                  0.379
# MSFT             0.173987             24.0                  0.350
#
#        Institutions Holding Shares  Interest Coverage (MRQ)  Last (size)  \
# AAPL                        5465.0                   336.41         50.0
# GOOGL                       4855.0                    15.59        500.0
# MSFT                        5914.0                      NaN          8.0
#
#              Last (time)  Last Trade Market Cap Market Edge Opinion:  \
# AAPL   1:00p ET 11/25/22         NaN       2.4T   Neutral From Avoid
# GOOGL  1:00p ET 11/25/22         NaN       1.3T   Neutral From Avoid
# MSFT   1:00p ET 11/25/22      245.65       1.8T   Neutral From Avoid
#
#        Net Profit Margin (TTM) Next Earnings Announcement  \
# AAPL                    0.2531        2023-01-26 00:00:00
# GOOGL                   0.2375        2023-01-31 00:00:00
# MSFT                    0.3437        2023-01-24 00:00:00
#
#        Operating Profit Margin (TTM) P/E Ratio (TTM, GAAP)  \
# AAPL                          0.3029                 24.27
# GOOGL                         0.2785                 19.73
# MSFT                          0.4163                 26.67
#
#        PEG Ratio (TTM, GAAP)  Prev Close  Price  Price/Book (MRQ)  \
# AAPL                    2.73      151.07    NaN          46.60129
# GOOGL                   2.20       98.46    NaN           4.98432
# MSFT                    2.05      247.49    NaN          10.63303
#
#        Price/Cash Flow (TTM)  Price/Earnings (TTM)  \
# AAPL                21.24439              24.27197
# GOOGL               15.36439              19.72627
# MSFT                22.00851              26.66797
#
#        Price/Earnings (TTM, GAAP)  Price/Sales (TTM)  Quick Ratio (MRQ)  \
# AAPL                        24.27            5.97511               0.85
# GOOGL                       19.73            4.47437               2.47
# MSFT                        26.67            9.08486               1.79
#
#        Return On Assets (TTM)  Return On Equity (TTM)  \
# AAPL                   0.2836                  1.7546
# GOOGL                  0.1899                  0.2689
# MSFT                   0.2008                  0.4288
#
#        Return On Investment (TTM)  Revenue Growth (MRQ)  Revenue Growth (TTM)  \
# AAPL                       0.4704                0.0866                0.0779
# GOOGL                      0.2318               -0.0085                0.1794
# MSFT                       0.2647               -0.0336                0.1522
#
#        Revenue Growth 5yr  Revenue Per Employee (TTM)  Shares Outstanding  \
# AAPL             0.114591                   2404439.0           15908.120
# GOOGL            0.233363                   1802639.0           12943.000
# MSFT             0.154734                    918891.0            7454.473
#
#        Short Int Current Month  Short Int Pct of Float  Short Int Prev Month  \
# AAPL               114431895.0                0.007199           103178670.0
# GOOGL               53117948.0                0.009003            51989928.0
# MSFT                34590231.0                0.004644            36909448.0
#
#        Short Interest  Today's Open  Total Debt/Total Capital (MRQ)  \
# AAPL           0.0072        148.31                          0.7032
# GOOGL          0.0090         98.24                          0.0561
# MSFT           0.0046           NaN                          0.2671
#
#            Volume  Volume 10-day Avg Volume Past Day cfra cfra since  \
# AAPL   35195860.0         72685349.0         (Light)  NaN 2017-08-02
# GOOGL   9701441.0         28516948.0         (Light)  NaN 2022-04-27
# MSFT      21087.0         26636518.0         (Light)  NaN 2020-07-25
#
#              ford ford since  marketEdge  marketEdge opinion  \
# AAPL   rating-box 2022-10-21  rating-box                 NaN
# GOOGL  rating-box 2022-04-08         NaN                 NaN
# MSFT   rating-box 2022-03-25         NaN                 NaN
#
#       marketEdge opinion since marketEdge since newConstructs  \
# AAPL                       NaT       2009-04-13    rating-box
# GOOGL                      NaT              NaT    rating-box
# MSFT                       NaT              NaT    rating-box
#
#       newConstructs since researchTeam researchTeam since   theStreet  \
# AAPL           2022-11-26   rating-box         2022-10-21         NaN
# GOOGL          2022-11-26   rating-box         2022-04-08  rating-box
# MSFT           2022-11-28   rating-box         2022-03-25  rating-box
#
#       theStreet since
# AAPL              NaT
# GOOGL      2018-04-24
# MSFT       2018-04-27

# %%
nmr_us['marketEdge opinion']
# Out:
# 0.0

# %%
nmr_us.loc['NVDA']
# Out:
# % Above Low                            0.5047
# % Below High                              NaN
# % Held by Institutions                 0.6318
# 52-Wk Range               ['108.13 - 334.12']
# 5yr Avg Return                        0.39695
#                                  ...
# newConstructs since       2022-11-28 00:00:00
# researchTeam                       rating-box
# researchTeam since        2022-08-26 00:00:00
# theStreet                          rating-box
# theStreet since           2022-09-16 00:00:00
# Name: NVDA, Length: 104, dtype: object

# %%
nmr_us[nmr_us['PEG Ratio (TTM, GAAP)'] < 1]
# Out:
#       % Above Low  % Below High  % Held by Institutions          52-Wk Range  \
# ABG           NaN        0.1097                  1.0572  ['138.88 - 203.92']
# ACLS          NaN        0.0520                  0.8845    ['46.41 - 83.74']
# AEL           NaN        0.1252                  0.9878    ['28.05 - 44.49']
# AIG           NaN        0.0707                  0.9005    ['47.05 - 65.73']
# ALB           NaN        0.1845                  0.8290  ['169.93 - 334.55']
# ...           ...           ...                     ...                  ...
# WCC           NaN        0.1567                  0.9451   ['99.00 - 147.05']
# WHD           NaN        0.2074                  1.0363    ['34.70 - 64.18']
# WRK        0.2041           NaN                  0.8753    ['30.08 - 54.78']
# WSC           NaN        0.0355                  0.9919    ['30.52 - 49.02']
# XOM           NaN        0.0423                  0.5789   ['57.96 - 114.66']
#
#       5yr Avg Return  5yr High  5yr Low  Annual Dividend $  Annual Dividend %  \
# ABG         0.210267    230.97    39.36                NaN                NaN
# ACLS        0.262233     83.74    12.99                NaN                NaN
# AEL         0.054817     44.49     9.07               0.36             0.0092
# AIG         0.050317     65.73    16.07               1.28             0.0210
# ALB         0.197500    334.55    48.89               1.58             0.0058
# ...              ...       ...      ...                ...                ...
# WCC         0.156333    147.05    13.52                NaN                NaN
# WHD         0.218840     64.18     8.16               0.44             0.0083
# WRK        -0.063083     71.55    21.50               1.10             0.0293
# WSC         0.356150     49.02     7.45                NaN                NaN
# XOM         0.120017    114.66    30.11               3.64             0.0322
#
#       Annual Dividend Yield     Ask  Ask Size  Ask close  B/A Ratio  \
# ABG                     NaN  182.23       NaN        NaN        NaN
# ACLS                    NaN   79.92     800.0        NaN   0.125000
# AEL                  0.0092   39.24       NaN        NaN        NaN
# AIG                  0.0210   65.00    1100.0        NaN   4.454545
# ALB                  0.0058  271.80     100.0        NaN   1.000000
# ...                     ...     ...       ...        ...        ...
# WCC                     NaN  147.00     100.0        NaN   1.000000
# WHD                  0.0083   57.68     400.0        NaN   0.750000
# WRK                  0.0293   47.00     100.0        NaN   3.000000
# WSC                     NaN   47.58     100.0        NaN   1.000000
# XOM                  0.0322  109.95     100.0        NaN   1.000000
#
#        B/A Size  Beta     Bid  Bid Size  Bid close Change Since Close  \
# ABG          --   1.1     NaN       NaN        NaN                NaN
# ACLS    100x800   1.6   78.84     100.0        NaN                NaN
# AEL          --   1.0     NaN       NaN        NaN                NaN
# AIG   4900x1100   1.2   60.98    4900.0        NaN                NaN
# ALB     100x100   1.4  271.55     100.0        NaN                NaN
# ...         ...   ...     ...       ...        ...                ...
# WCC     100x100   2.0   98.41     100.0        NaN                NaN
# WHD     300x400   1.9   39.89     300.0        NaN                NaN
# WRK     300x100   1.1   31.96     300.0        NaN                NaN
# WSC     100x100   1.5   47.12     100.0        NaN                NaN
# XOM     100x100   1.1  109.71     100.0        NaN                NaN
#
#       Change in Debt/Total Capital Quarter over Quarter  Closing Price  \
# ABG                                              0.0002         181.56
# ACLS                                            -0.0023          79.38
# AEL                                              0.0070          38.92
# AIG                                              0.0100          61.08
# ALB                                              0.0031         272.82
# ...                                                 ...            ...
# WCC                                              0.0002         124.01
# WHD                                              0.0006          50.87
# WRK                                             -0.0002          36.22
# WSC                                              0.0009          47.28
# XOM                                             -0.0027         109.81
#
#       Day Change $  Day Change %  Day High  Day Low  Days to Cover  \
# ABG          -0.34       -0.0019    183.30   179.98       11.42292
# ACLS          0.31        0.0039     79.59    78.05        2.67814
# AEL          -0.11       -0.0028     39.41    38.81        1.13859
# AIG           0.12        0.0020     61.43    60.97        1.23183
# ALB         -11.08       -0.0390    277.68   266.71        1.17735
# ...            ...           ...       ...      ...            ...
# WCC          -3.79       -0.0297    127.07   123.43        2.00156
# WHD          -2.02       -0.0382     52.63    50.39        4.02829
# WRK          -1.29       -0.0344     37.21    36.07        1.37863
# WSC          -0.74       -0.0154     48.02    47.14        1.97865
# XOM          -3.40       -0.0300    111.46   109.62        2.17440
#
#       Dividend Change %  Dividend Growth 5yr  Dividend Growth Rate, 3 Years  \
# ABG                 NaN                  NaN                            NaN
# ACLS                NaN                  NaN                            NaN
# AEL              0.0625             0.072145                         0.0669
# AIG              0.0000             0.000000                         0.0000
# ALB              0.0213             0.052322                         0.0548
# ...                 ...                  ...                            ...
# WCC                 NaN                  NaN                            NaN
# WHD              0.0556                  NaN                            NaN
# WRK              0.1364            -0.089718                        -0.1810
# WSC                 NaN                  NaN                            NaN
# XOM              0.0029             0.032100                         0.0261
#
#         Dividend Pay Date  EPS (TTM, GAAP)  EPS Growth (MRQ)  \
# ABG           No dividend            35.10            0.0179
# ACLS          No dividend             4.80           -0.0837
# AEL   2022-12-13 00:00:00            13.70           -0.0905
# AIG   2022-12-29 00:00:00            16.85           -0.0737
# ALB   2023-01-03 00:00:00            13.19            1.2030
# ...                   ...              ...               ...
# WCC           No dividend            14.50            0.1211
# WHD   2022-12-15 00:00:00             1.55            0.1577
# WRK   2022-11-23 00:00:00             3.65           -0.0848
# WSC           No dividend             1.27            0.3372
# XOM   2022-12-09 00:00:00            12.26            0.1140
#
#       EPS Growth (TTM)  EPS Growth 5yr          Ex-dividend Ex-dividend Date  \
# ABG             0.4143        0.290574                  NaN      No dividend
# ACLS            1.1213        0.519423                  NaN      No dividend
# AEL             2.8155        0.361788  2022-11-25 00:00:00         11/25/22
# AIG             1.6449             NaN  2022-12-14 00:00:00         12/14/22
# ALB             5.9765       -0.229156  2022-12-15 00:00:00         12/15/22
# ...                ...             ...                  ...              ...
# WCC             1.8906        0.301235                  NaN      No dividend
# WHD             1.3463             NaN  2022-11-25 00:00:00         11/25/22
# WRK             0.1653        0.054565  2022-11-09 00:00:00         11/09/22
# WSC             2.7452             NaN                  NaN      No dividend
# XOM             9.8450        0.234294  2022-11-14 00:00:00         11/14/22
#
#       FCF Growth 5yr       Float  Gross Profit Margin (TTM)  \
# ABG        -0.026798    21.97417                     0.2020
# ACLS        0.525222    32.19281                     0.4441
# AEL         1.238036    84.18821                        NaN
# AIG              NaN   740.82660                        NaN
# ALB         4.588352   116.96330                     0.4135
# ...              ...         ...                        ...
# WCC        -5.128845    37.11134                     0.2149
# WHD         0.821372    60.32379                     0.3329
# WRK         1.677572   251.18750                     0.1892
# WSC         0.370599   202.29910                     0.5288
# XOM         0.502743  4115.09100                     0.3105
#
#       Growth 1yr Consensus Est  Growth 1yr High Est  Growth 1yr Low Est  \
# ABG                   1.990233             1.984615            1.995851
# ACLS                  2.686926             2.510949            2.862903
# AEL                        NaN                  NaN                 NaN
# AIG                   0.880682             1.053030            0.708333
# ALB                   4.273039             4.404306            4.141772
# ...                        ...                  ...                 ...
# WCC                   2.069974             2.066163            2.073786
# WHD                  -0.016543             0.005376           -0.038462
# WRK                  -0.174548            -0.153061           -0.196035
# WSC                   1.040419             1.012346            1.068493
# XOM                   1.645568             1.722426            1.568710
#
#       Growth 2yr Consensus Est  Growth 2yr High Est  Growth 2yr Low Est  \
# ABG                   0.904297             0.967179            0.841416
# ACLS                  1.372571             1.312647            1.432495
# AEL                   0.229200             0.260870            0.197531
# AIG                   0.607270             0.671349            0.543191
# ALB                   2.322943             2.582631            2.063254
# ...                        ...                  ...                 ...
# WCC                   0.995000             1.074080            0.915920
# WHD                   0.169139             0.203223            0.135055
# WRK                  -0.086061            -0.004241           -0.167881
# WSC                   0.599477             0.677952            0.521002
# XOM                   0.730890             0.837918            0.623861
#
#       Growth 3yr Historic  Growth 5yr Actual/Est  Growth 5yr Consensus Est  \
# ABG              0.369785               0.421239                  0.536921
# ACLS             0.708333               0.888021                  0.915047
# AEL              0.554740               0.699917                  0.229200
# AIG              0.145191               0.216260                  0.184629
# ALB             -0.084325               1.051452                  1.079229
# ...                   ...                    ...                       ...
# WCC              0.281034               0.439346                  0.497500
# WHD             -0.155306               0.305446                  0.084569
# WRK              0.158098               0.117678                  0.123742
# WSC              0.254234               0.542637                  0.623425
# XOM             -4.612588              -4.263721                 -6.001044
#
#       Growth 5yr High Est  Growth 5yr Low Est  Growth Analysts  \
# ABG              0.574618            0.499225              9.0
# ACLS             0.875098            0.954997              6.0
# AEL              0.260870            0.197531              3.0
# AIG              0.214330            0.154929             16.0
# ALB              1.208894            0.949564             22.0
# ...                   ...                 ...              ...
# WCC              0.537040            0.457960             13.0
# WHD              0.101611            0.067527              7.0
# WRK              0.164908            0.082576             12.0
# WSC              0.447903            0.798947              5.0
# XOM             -9.318581           -2.683508             25.0
#
#       Historical Volatility  Institutions Holding Shares  \
# ABG                   0.506                        362.0
# ACLS                  0.685                        383.0
# AEL                   0.468                        346.0
# AIG                   0.337                       1199.0
# ALB                   0.556                       1305.0
# ...                     ...                          ...
# WCC                   0.496                        479.0
# WHD                   0.564                        292.0
# WRK                   0.369                        831.0
# WSC                   0.388                        469.0
# XOM                   0.349                       3756.0
#
#       Interest Coverage (MRQ)  Last (size)        Last (time)  Last Trade  \
# ABG                      7.74         10.0  5:00p ET 11/25/22         NaN
# ACLS                   239.65          1.0  1:00p ET 11/25/22         NaN
# AEL                       NaN         34.0  5:00p ET 11/25/22         NaN
# AIG                     19.05          9.0  5:00p ET 11/25/22         NaN
# ALB                     30.11        100.0  5:00p ET 11/25/22         NaN
# ...                       ...          ...                ...         ...
# WCC                      5.35          1.0  7:00p ET 11/28/22         NaN
# WHD                       NaN          1.0  7:00p ET 11/28/22         NaN
# WRK                      7.33         13.0  7:00p ET 11/28/22         NaN
# WSC                      4.12          1.0  4:00p ET 11/28/22         NaN
# XOM                       NaN        100.0  7:00p ET 11/28/22         NaN
#
#      Market Cap Market Edge Opinion:  Net Profit Margin (TTM)  \
# ABG        4.0B                 Long                   0.0546
# ACLS       2.6B                 Long                   0.1883
# AEL        3.3B    Neutral From Long                   0.7125
# AIG       45.4B                 Long                   0.2578
# ALB       32.0B                Avoid                   0.2111
# ...         ...                  ...                      ...
# WCC        6.3B                Avoid                   0.0391
# WHD        3.1B                  NaN                   0.1979
# WRK        9.2B   Neutral From Avoid                   0.0447
# WSC        9.9B                  NaN                   0.1315
# XOM      452.2B                 Long                   0.1384
#
#      Next Earnings Announcement  Operating Profit Margin (TTM)  \
# ABG         2023-02-14 00:00:00                         0.0842
# ACLS        2023-02-06 00:00:00                         0.2360
# AEL         2023-02-16 00:00:00                        -0.4145
# AIG         2023-02-15 00:00:00                         0.3420
# ALB         2023-02-15 00:00:00                         0.2868
# ...                         ...                            ...
# WCC         2023-02-16 00:00:00                         0.0616
# WHD         2023-03-01 00:00:00                         0.2415
# WRK         2023-02-02 00:00:00                         0.0620
# WSC         2023-02-23 00:00:00                         0.2265
# XOM         2023-02-03 00:00:00                         0.1423
#
#      P/E Ratio (TTM, GAAP)  PEG Ratio (TTM, GAAP)  Prev Close  Price  \
# ABG                   5.17                   0.28      181.90    NaN
# ACLS                 16.55                   0.83       79.07    NaN
# AEL                   2.84                   0.12       39.03    NaN
# AIG                   3.62                   0.31       60.96    NaN
# ALB                  20.69                   0.27      283.90    NaN
# ...                    ...                    ...         ...    ...
# WCC                   8.82                   0.88      127.80    NaN
# WHD                  34.19                   0.59       52.89    NaN
# WRK                  10.29                   0.90       37.51    NaN
# WSC                  37.75                   0.69       48.02    NaN
# XOM                   9.23                   0.36      113.21    NaN
#
#       Price/Book (MRQ)  Price/Cash Flow (TTM)  Price/Earnings (TTM)  \
# ABG            1.52048                4.73040               5.17239
# ACLS           4.25204               15.04856              16.54529
# AEL            1.04307                2.55940               2.84085
# AIG            1.18428                2.25463               3.62441
# ALB            4.74695               21.82727              20.68660
# ...                ...                    ...                   ...
# WCC            1.54702                6.89184               8.81638
# WHD            7.37394               25.14769              34.19163
# WRK            0.83692                3.91539              10.29033
# WSC            6.03396               17.80597              37.75068
# XOM            2.50510                6.33551               9.23286
#
#       Price/Earnings (TTM, GAAP)  Price/Sales (TTM)  Quick Ratio (MRQ)  \
# ABG                         5.17            0.27940               0.85
# ACLS                       16.55            3.03331               2.64
# AEL                         2.84            1.78341                NaN
# AIG                         3.62            0.76998                NaN
# ALB                        20.69            5.71424               1.08
# ...                          ...                ...                ...
# WCC                         8.82            0.31370               1.24
# WHD                        34.19            6.36499               3.51
# WRK                        10.29            0.44904               0.94
# WSC                        37.75            4.66497               0.81
# XOM                         9.23            1.20522               1.02
#
#       Return On Assets (TTM)  Return On Equity (TTM)  \
# ABG                   0.1378                  0.3979
# ACLS                  0.2001                  0.2873
# AEL                   0.0179                  0.2690
# AIG                   0.0272                  0.2667
# ALB                   0.0958                  0.2500
# ...                      ...                     ...
# WCC                   0.0610                  0.1931
# WHD                   0.1212                  0.1882
# WRK                   0.0329                  0.0819
# WSC                   0.0494                  0.1554
# XOM                   0.1515                  0.2989
#
#       Return On Investment (TTM)  Revenue Growth (MRQ)  Revenue Growth (TTM)  \
# ABG                       0.1640               -0.0213                0.5273
# ACLS                      0.2544                0.0362                0.4848
# AEL                          NaN                3.0517               -0.4819
# AIG                          NaN                0.0111                0.2370
# ALB                       0.1172                0.4138                0.6883
# ...                          ...                   ...                   ...
# WCC                       0.0816               -0.0069                0.1840
# WHD                       0.1575                0.0838                0.6735
# WRK                       0.0379               -0.0212                0.1339
# WSC                       0.0549                0.1635                0.2406
# XOM                       0.1922               -0.0427                0.6042
#
#       Revenue Growth 5yr  Revenue Per Employee (TTM)  Shares Outstanding  \
# ABG             0.085489                   1012866.0            22.13306
# ACLS            0.199311                    766160.0            32.84862
# AEL             0.106907                   2337885.0            85.70226
# AIG            -0.003034                   1610328.0           742.98000
# ALB             0.044478                    932222.0           117.15280
# ...                  ...                         ...                 ...
# WCC             0.199515                   1150752.0            50.84367
# WHD             0.231171                    608014.0            75.87812
# WRK             0.074228                    420921.0           254.46400
# WSC             0.347443                    457502.0           208.88980
# XOM             0.066402                   6139937.0          4118.00000
#
#       Short Int Current Month  Short Int Pct of Float  Short Int Prev Month  \
# ABG                 1980255.0                0.090116             1989796.0
# ACLS                1131722.0                0.035121             1257567.0
# AEL                 1240879.0                0.014748             1265860.0
# AIG                 6330607.0                0.008547             6366744.0
# ALB                 1991174.0                0.017024             2143797.0
# ...                       ...                     ...                   ...
# WCC                 1606841.0                0.036604             1322882.0
# WHD                 1660776.0                0.027522             1980151.0
# WRK                 3795961.0                0.015115             3375312.0
# WSC                 4691214.0                0.023176             8076889.0
# XOM                41236390.0                0.010025            45167966.0
#
#       Short Interest  Today's Open  Total Debt/Total Capital (MRQ)  \
# ABG           0.0901        179.98                          0.5593
# ACLS          0.0351         78.17                          0.0706
# AEL           0.0147         39.33                          0.2139
# AIG           0.0085         61.36                          0.5752
# ALB           0.0170        276.80                          0.3261
# ...              ...           ...                             ...
# WCC           0.0366        126.04                          0.5566
# WHD           0.0275         51.29                          0.0183
# WRK           0.0151         37.04                          0.4053
# WSC           0.0232         47.70                          0.6369
# XOM           0.0100        110.66                          0.1905
#
#           Volume  Volume 10-day Avg  Volume Past Day cfra cfra since  \
# ABG      39325.0           145095.0          (Light)  NaN 2020-07-14
# ACLS     93576.0           362111.0          (Light)  NaN        NaT
# AEL     203025.0           466206.0          (Light)  NaN        NaT
# AIG    2160455.0          4270528.0          (Light)  NaN 2020-08-05
# ALB    1341936.0          1550929.0  (Below Average)  NaN 2021-05-06
# ...          ...                ...              ...  ...        ...
# WCC     286572.0           454942.0          (Light)  NaN        NaT
# WHD     506925.0           366733.0      (Heavy Day)  NaN        NaT
# WRK    1657236.0          1959023.0  (Below Average)  NaN 2022-11-11
# WSC    1555257.0          1387111.0  (Above Average)  NaN        NaT
# XOM   23017671.0         16598643.0      (Heavy Day)  NaN 2021-07-19
#
#             ford ford since  marketEdge  marketEdge opinion  \
# ABG   rating-box 2022-10-21  rating-box                 NaN
# ACLS  rating-box 2022-09-09  rating-box                 NaN
# AEL   rating-box 2022-11-11  rating-box                 NaN
# AIG   rating-box 2022-10-07  rating-box                 NaN
# ALB   rating-box 2022-11-11  rating-box                 NaN
# ...          ...        ...         ...                 ...
# WCC   rating-box 2022-10-28         NaN                 NaN
# WHD   rating-box 2022-09-30         NaN                 NaN
# WRK   rating-box 2022-10-28         NaN                 NaN
# WSC   rating-box 2022-11-11         NaN                 NaN
# XOM   rating-box 2022-11-04         NaN                 NaN
#
#      marketEdge opinion since marketEdge since newConstructs  \
# ABG                       NaT       2020-07-15    rating-box
# ACLS                      NaT       2020-05-14    rating-box
# AEL                       NaT       2020-12-14    rating-box
# AIG                       NaT       2022-10-28    rating-box
# ALB                       NaT       2022-05-05    rating-box
# ...                       ...              ...           ...
# WCC                       NaT              NaT    rating-box
# WHD                       NaT              NaT    rating-box
# WRK                       NaT              NaT    rating-box
# WSC                       NaT              NaT    rating-box
# XOM                       NaT              NaT    rating-box
#
#      newConstructs since researchTeam researchTeam since   theStreet  \
# ABG           2022-11-25   rating-box         2021-07-23         NaN
# ACLS          2022-11-25   rating-box         2021-08-06         NaN
# AEL           2022-11-25   rating-box         2022-11-11         NaN
# AIG           2022-11-25   rating-box         2022-06-24         NaN
# ALB           2022-11-25   rating-box         2022-09-23         NaN
# ...                  ...          ...                ...         ...
# WCC           2022-11-26   rating-box         2022-10-28  rating-box
# WHD           2022-11-26   rating-box         2022-08-05  rating-box
# WRK           2022-11-26   rating-box         2022-08-20  rating-box
# WSC           2022-11-26   rating-box         2022-11-11  rating-box
# XOM           2022-11-28   rating-box         2022-08-20  rating-box
#
#      theStreet since
# ABG              NaT
# ACLS             NaT
# AEL              NaT
# AIG              NaT
# ALB              NaT
# ...              ...
# WCC       2021-06-09
# WHD       2022-03-01
# WRK       2022-10-10
# WSC       2021-10-14
# XOM       2022-01-20
#
# [95 rows x 104 columns]

# %%
nmr_us[(nmr_us['Growth 1yr Consensus Est'] > 0) & (nmr_us['Growth 2yr Consensus Est'] > 0)]
# Out:
#       % Above Low  % Below High  % Held by Institutions          52-Wk Range  \
# A             NaN        0.0348                  0.8930  ['112.52 - 162.62']
# AADI       0.2109           NaN                  0.6271    ['11.00 - 26.60']
# AAON          NaN        0.0624                  0.7017    ['47.50 - 83.79']
# AAP        0.0303           NaN                  0.9798  ['145.59 - 244.55']
# AAPL       0.1478           NaN                  0.5798  ['129.04 - 182.94']
# ...           ...           ...                     ...                  ...
# XOM           NaN        0.0423                  0.5789   ['57.96 - 114.66']
# XPEL          NaN        0.2320                  0.6033    ['39.80 - 87.01']
# XYL           NaN        0.1258                  0.8910   ['72.08 - 125.38']
# ZTS        0.1932           NaN                  0.9115  ['124.15 - 249.27']
# ZYXI          NaN        0.0715                  0.2850     ['4.97 - 14.55']
#
#       5yr Avg Return  5yr High  5yr Low  Annual Dividend $  Annual Dividend %  \
# A           0.159983    179.57    60.42               0.90             0.0057
# AADI       -0.102367     82.50     6.30                NaN                NaN
# AAON        0.153133     83.79    29.05               0.48             0.0061
# AAP         0.137133    244.55    71.33               6.00             0.0400
# AAPL        0.290700    182.94    35.50               0.92             0.0062
# ...              ...       ...      ...                ...                ...
# XOM         0.120017    114.66    30.11               3.64             0.0322
# XPEL        1.237133    103.84     1.32                NaN                NaN
# XYL         0.091717    138.78    54.62               1.20             0.0106
# ZTS         0.180483    249.27    70.20               1.30             0.0087
# ZYXI        0.438817     27.02     1.68                NaN                NaN
#
#       Annual Dividend Yield     Ask  Ask Size  Ask close  B/A Ratio  B/A Size  \
# A                    0.0057  156.96     100.0        NaN      5.000   500x100
# AADI                    NaN   20.73     200.0        NaN      2.500   500x200
# AAON                 0.0061  126.28     200.0        NaN      1.500   300x200
# AAP                  0.0400  150.30     500.0        NaN      0.800   400x500
# AAPL                 0.0062  148.12     800.0        NaN      5.875  4700x800
# ...                     ...     ...       ...        ...        ...       ...
# XOM                  0.0322  109.95     100.0        NaN      1.000   100x100
# XPEL                    NaN   71.13     200.0        NaN      6.000  1200x200
# XYL                  0.0106  119.40     500.0        NaN      0.200   100x500
# ZTS                  0.0088  155.63     800.0        NaN      1.750  1400x800
# ZYXI                    NaN   13.51     400.0        NaN      5.500  2200x400
#
#       Beta     Bid  Bid Size  Bid close Change Since Close  \
# A      1.1  152.40     500.0        NaN                NaN
# AADI   1.3   12.85     500.0        NaN                NaN
# AAON   0.8   70.56     300.0        NaN                NaN
# AAP    1.2  149.50     400.0        NaN                NaN
# AAPL   1.2  148.11    4700.0        NaN                NaN
# ...    ...     ...       ...        ...                ...
# XOM    1.1  109.71     100.0        NaN                NaN
# XPEL   1.5   66.00    1200.0        NaN                NaN
# XYL    1.1   61.70     100.0        NaN                NaN
# ZTS    0.7  143.05    1400.0        NaN                NaN
# ZYXI   0.8   13.49    2200.0        NaN                NaN
#
#       Change in Debt/Total Capital Quarter over Quarter  Closing Price  \
# A                                                0.0003         156.96
# AADI                                            -0.0100          13.32
# AAON                                             0.0750          78.56
# AAP                                              0.0030         150.00
# AAPL                                            -0.0005         148.11
# ...                                                 ...            ...
# XOM                                             -0.0027         109.81
# XPEL                                             0.2881          66.82
# XYL                                             -0.0003         109.61
# ZTS                                              0.0000         148.13
# ZYXI                                             0.1993          13.51
#
#       Day Change $  Day Change %  Day High  Day Low  Days to Cover  \
# A             1.61        0.0104    156.96   154.71        2.27041
# AADI          0.15        0.0114     13.43    13.25       10.56765
# AAON          0.15        0.0019     79.48    78.43        2.80083
# AAP          -0.55       -0.0037    150.78   148.35        3.47300
# AAPL         -2.96       -0.0196    148.88   147.12        1.21464
# ...            ...           ...       ...      ...            ...
# XOM          -3.40       -0.0300    111.46   109.62        2.17440
# XPEL         -1.76       -0.0257     68.65    66.76        8.28761
# XYL          -3.89       -0.0343    112.68   108.81        3.67735
# ZTS          -1.97       -0.0131    149.98   147.82        1.08693
# ZYXI         -0.02       -0.0015     13.76    13.39       12.69665
#
#       Dividend Change %  Dividend Growth 5yr  Dividend Growth Rate, 3 Years  \
# A                0.0814             0.100275                         0.0873
# AADI                NaN                  NaN                            NaN
# AAON             0.0000             0.096262                         0.0590
# AAP              2.0660             0.683970                         1.3835
# AAPL             0.0588             0.084472                         0.0627
# ...                 ...                  ...                            ...
# XOM              0.0029             0.032100                         0.0261
# XPEL                NaN                  NaN                            NaN
# XYL              0.0769             0.125696                         0.1006
# ZTS              0.2500             0.207222                         0.2566
# ZYXI                NaN                  NaN                            NaN
#
#         Dividend Pay Date  EPS (TTM, GAAP)  EPS Growth (MRQ)  \
# A     2023-01-25 00:00:00             4.18            0.1223
# AADI          No dividend            -2.97            0.2189
# AAON  2022-12-16 00:00:00             1.26            0.7134
# AAP   2023-01-03 00:00:00             7.77           -0.2264
# AAPL  2022-11-10 00:00:00             6.10            0.0753
# ...                   ...              ...               ...
# XOM   2022-12-09 00:00:00            12.26            0.1140
# XPEL          No dividend             1.42            0.1187
# XYL   2022-12-20 00:00:00             1.76           -0.8930
# ZTS   2022-12-01 00:00:00             4.38            0.0051
# ZYXI          No dividend             0.47            0.4949
#
#       EPS Growth (TTM)  EPS Growth 5yr          Ex-dividend Ex-dividend Date  \
# A               0.0613        0.147804  2022-12-30 00:00:00         12/30/22
# AADI            0.7442             NaN                  NaN      No dividend
# AAON           -0.0585        0.018337  2022-11-25 00:00:00         11/25/22
# AAP            -0.2131        0.090367  2022-12-15 00:00:00         12/15/22
# AAPL            0.0883        0.215750  2022-11-04 00:00:00         11/04/22
# ...                ...             ...                  ...              ...
# XOM             9.8450        0.234294  2022-11-14 00:00:00         11/14/22
# XPEL            0.2471        0.678053                  NaN      No dividend
# XYL            -0.3080        0.102479  2022-11-21 00:00:00         11/21/22
# ZTS             0.0538        0.209937  2022-10-31 00:00:00         10/31/22
# ZYXI            0.8353        1.933079                  NaN      No dividend
#
#       FCF Growth 5yr        Float  Gross Profit Margin (TTM)  \
# A           0.805355    294.17500                     0.5435
# AADI        0.233978     20.63551                     0.8077
# AAON       -1.753292     42.26687                     0.2409
# AAP        -0.754292     58.78215                     0.4465
# AAPL        0.369541  15896.63000                     0.4331
# ...              ...          ...                        ...
# XOM         0.502743   4115.09100                     0.3105
# XPEL       -1.004230     19.42917                     0.3838
# XYL        -1.424801    178.75350                     0.3754
# ZTS         0.353294    464.87150                     0.7019
# ZYXI        1.471637     20.79778                     0.8013
#
#       Growth 1yr Consensus Est  Growth 1yr High Est  Growth 1yr Low Est  \
# A                     0.145669             0.156863            0.134474
# AADI                  3.956897             3.879310            4.034483
# AAON                  0.192745             0.215278            0.170213
# AAP                   0.074210             0.095833            0.052587
# AAPL                  0.028248             0.092210           -0.035714
# ...                        ...                  ...                 ...
# XOM                   1.645568             1.722426            1.568710
# XPEL                  1.584203             1.545455            1.622951
# XYL                   0.108091             0.100000            0.116183
# ZTS                   0.044979             0.048832            0.041126
# ZYXI                  0.020717            -0.063830            0.105263
#
#       Growth 2yr Consensus Est  Growth 2yr High Est  Growth 2yr Low Est  \
# A                     0.120040             0.127584            0.112496
# AADI                  1.933734             1.815980            2.051488
# AAON                  0.303083             0.336210            0.269955
# AAP                   0.019678             0.112175           -0.072820
# AAPL                  0.060196             0.081767            0.038624
# ...                        ...                  ...                 ...
# XOM                   0.730890             0.837918            0.623861
# XPEL                  0.959140             0.966180            0.952100
# XYL                   0.141947             0.168182            0.115712
# ZTS                   0.068351             0.092230            0.044471
# ZYXI                  0.194612             0.229449            0.159774
#
#       Growth 3yr Historic  Growth 5yr Actual/Est  Growth 5yr Consensus Est  \
# A                0.131484               0.176900                  0.156938
# AADI             1.612193               1.389829                  0.966867
# AAON             0.051262               0.276465                  0.254329
# AAP              0.112882               0.142781                  0.127222
# AAPL             0.199873               0.228001                  0.226432
# ...                   ...                    ...                       ...
# XOM             -4.612588              -4.263721                 -6.001044
# XPEL             0.262923               0.451640                  0.639427
# XYL             -0.027286               0.035393                  0.024525
# ZTS              0.069618               0.105832                  0.104551
# ZYXI             0.189103               0.282258                  0.247028
#
#       Growth 5yr High Est  Growth 5yr Low Est  Growth Analysts  \
# A                0.177692            0.136184             17.0
# AADI             0.907990            1.025744              4.0
# AAON             0.267620            0.241038              3.0
# AAP              0.172884            0.081559             25.0
# AAPL             0.236640            0.216224             39.0
# ...                   ...                 ...              ...
# XOM             -9.318581           -2.683508             25.0
# XPEL             0.644120            0.634734              2.0
# XYL              0.040362            0.008689             18.0
# ZTS              0.116606            0.092497             17.0
# ZYXI             0.284169            0.209887              5.0
#
#       Historical Volatility  Institutions Holding Shares  \
# A                     0.350                       1333.0
# AADI                  0.638                         91.0
# AAON                  0.384                        283.0
# AAP                   0.387                        892.0
# AAPL                  0.355                       5465.0
# ...                     ...                          ...
# XOM                   0.349                       3756.0
# XPEL                  0.552                        227.0
# XYL                   0.352                       1115.0
# ZTS                   0.317                       2015.0
# ZYXI                  1.255                        169.0
#
#       Interest Coverage (MRQ)  Last (size)        Last (time)  Last Trade  \
# A                       27.56         30.0  5:00p ET 11/25/22         NaN
# AADI                      NaN          7.0  1:00p ET 11/25/22         NaN
# AAON                    38.47         21.0  1:00p ET 11/25/22         NaN
# AAP                     15.30          2.0  5:00p ET 11/25/22         NaN
# AAPL                   336.41         50.0  1:00p ET 11/25/22         NaN
# ...                       ...          ...                ...         ...
# XOM                       NaN        100.0  7:00p ET 11/28/22         NaN
# XPEL                    22.68          1.0  4:00p ET 11/28/22         NaN
# XYL                     16.92        535.0  7:00p ET 11/28/22         NaN
# ZTS                     14.22         10.0  7:00p ET 11/28/22         NaN
# ZYXI                    61.87          1.0  3:59p ET 11/28/22         NaN
#
#      Market Cap Market Edge Opinion:  Net Profit Margin (TTM)  \
# A         46.5B                 Long                   0.1831
# AADI     324.9M                  NaN                  -5.6957
# AAON       4.2B                 Long                   0.0878
# AAP        8.9B    Neutral From Long                   0.0430
# AAPL       2.4T   Neutral From Avoid                   0.2531
# ...         ...                  ...                      ...
# XOM      452.2B                 Long                   0.1384
# XPEL       1.8B                  NaN                   0.1243
# XYL       19.8B                 Long                   0.0597
# ZTS       69.0B   Neutral From Avoid                   0.2578
# ZYXI     520.1M                  NaN                   0.1235
#
#      Next Earnings Announcement  Operating Profit Margin (TTM)  \
# A           2023-02-21 00:00:00                         0.2363
# AADI        2023-03-16 00:00:00                        -5.7471
# AAON        2023-03-01 00:00:00                         0.1111
# AAP         2023-02-13 00:00:00                         0.0620
# AAPL        2023-01-26 00:00:00                         0.3029
# ...                         ...                            ...
# XOM         2023-02-03 00:00:00                         0.1423
# XPEL        2023-02-27 00:00:00                         0.1635
# XYL         2023-02-02 00:00:00                         0.0798
# ZTS         2023-02-16 00:00:00                         0.3210
# ZYXI        2023-02-23 00:00:00                         0.1631
#
#      P/E Ratio (TTM, GAAP)  PEG Ratio (TTM, GAAP)  Prev Close  Price  \
# A                    37.55                   3.02      155.35    NaN
# AADI                   NaN                    NaN       13.17    NaN
# AAON                 62.56                    NaN       78.41    NaN
# AAP                  19.29                   1.54      150.55    NaN
# AAPL                 24.27                   2.73      151.07    NaN
# ...                    ...                    ...         ...    ...
# XOM                   9.23                   0.36      113.21    NaN
# XPEL                 48.28                    NaN       68.58    NaN
# XYL                  64.41                    NaN      113.50    NaN
# ZTS                  34.31                   3.36      150.10    NaN
# ZYXI                 28.87                    NaN       13.53    NaN
#
#       Price/Book (MRQ)  Price/Cash Flow (TTM)  Price/Earnings (TTM)  \
# A              8.75462               29.47371              37.55455
# AADI           1.92151                    NaN                   NaN
# AAON           7.98035               41.33924              62.55972
# AAP            3.29682               11.73707              19.29447
# AAPL          46.60129               21.24439              24.27197
# ...                ...                    ...                   ...
# XOM            2.50510                6.33551               9.23286
# XPEL          16.47551               40.58321              48.27878
# XYL            6.36165               36.92264              64.41105
# ZTS           15.01457               27.68398              34.30708
# ZYXI           7.86379               23.53998              28.87201
#
#       Price/Earnings (TTM, GAAP)  Price/Sales (TTM)  Quick Ratio (MRQ)  \
# A                          37.55            6.76157               1.47
# AADI                         NaN           29.56984              10.57
# AAON                       62.56            5.42441               1.12
# AAP                        19.29            0.80232               0.23
# AAPL                       24.27            5.97511               0.85
# ...                          ...                ...                ...
# XOM                         9.23            1.20522               1.02
# XPEL                       48.28            6.00014               1.11
# XYL                        64.41            3.83127               1.22
# ZTS                        33.86            8.73703               1.48
# ZYXI                       28.83            3.38444               2.68
#
#       Return On Assets (TTM)  Return On Equity (TTM)  \
# A                     0.1182                  0.2349
# AADI                 -0.3450                 -0.3911
# AAON                  0.1039                  0.1464
# AAP                   0.0397                  0.1613
# AAPL                  0.2836                  1.7546
# ...                      ...                     ...
# XOM                   0.1515                  0.2989
# XPEL                  0.2509                  0.4057
# XYL                   0.0392                  0.1011
# ZTS                   0.1508                  0.4425
# ZYXI                  0.1794                  0.2876
#
#       Return On Investment (TTM)  Revenue Growth (MRQ)  Revenue Growth (TTM)  \
# A                         0.1421                0.0763                0.0837
# AADI                     -0.3754                0.2351               90.5750
# AAON                      0.1246                0.1618                0.4963
# AAP                       0.0701               -0.0090                0.0102
# AAPL                      0.4704                0.0866                0.0779
# ...                          ...                   ...                   ...
# XOM                       0.1922               -0.0427                0.6042
# XPEL                      0.3191                0.0699                0.3277
# XYL                       0.0491                0.0117                0.0179
# ZTS                       0.1793               -0.0244                0.0513
# ZYXI                      0.2100                0.1295                0.2959
#
#       Revenue Growth 5yr  Revenue Per Employee (TTM)  Shares Outstanding  \
# A               0.088961                         NaN           295.00000
# AADI                 NaN                    281769.0            24.39512
# AAON            0.068394                    267432.0            53.19954
# AAP             0.028256                    270194.0            59.25372
# AAPL            0.114591                   2404439.0         15908.12000
# ...                  ...                         ...                 ...
# XOM             0.066402                   6139937.0          4118.00000
# XPEL            0.380227                    445196.0            27.61606
# XYL             0.066168                    308613.0           180.22150
# ZTS             0.097299                    661736.0           466.07200
# ZYXI            0.578099                    193447.0            37.45345
#
#       Short Int Current Month  Short Int Pct of Float  Short Int Prev Month  \
# A                   2889384.0                0.009829             2893740.0
# AADI                1061468.0                0.054996              937861.0
# AAON                 666129.0                0.015769              893577.0
# AAP                 3082173.0                0.052472             3096041.0
# AAPL              114431895.0                0.007199           103178670.0
# ...                       ...                     ...                   ...
# XOM                41236390.0                0.010025            45167966.0
# XPEL                1182907.0                0.079001             1297942.0
# XYL                 3849887.0                0.021539             3996020.0
# ZTS                 4041806.0                0.008695             4264101.0
# ZYXI                3352703.0                0.161271             3684031.0
#
#       Short Interest  Today's Open  Total Debt/Total Capital (MRQ)  \
# A             0.0098        155.09                          0.3436
# AADI          0.0550         13.30                          0.0000
# AAON          0.0158         78.45                          0.1364
# AAP           0.0525        150.76                          0.3358
# AAPL          0.0072        148.31                          0.7032
# ...              ...           ...                             ...
# XOM           0.0100        110.66                          0.1905
# XPEL          0.0790         68.22                          0.1853
# XYL           0.0215        112.46                          0.4231
# ZTS           0.0087        149.46                          0.5847
# ZYXI          0.1613         13.53                          0.1588
#
#           Volume  Volume 10-day Avg Volume Past Day cfra cfra since  \
# A       642657.0          1531121.0         (Light)  NaN 2021-08-18
# AADI     28331.0            83176.0         (Light)  NaN        NaT
# AAON     42676.0           190222.0         (Light)  NaN        NaT
# AAP     579430.0          1764984.0         (Light)  NaN 2022-11-16
# AAPL  35195860.0         72685349.0         (Light)  NaN 2017-08-02
# ...          ...                ...             ...  ...        ...
# XOM   23017671.0         16598643.0     (Heavy Day)  NaN 2021-07-19
# XPEL     90100.0           122542.0         (Light)  NaN        NaT
# XYL    1184873.0           742090.0     (Heavy Day)  NaN 2022-02-03
# ZTS    1633281.0          2245113.0         (Light)  NaN 2022-01-10
# ZYXI    122690.0           177167.0         (Light)  NaN        NaT
#
#             ford ford since  marketEdge  marketEdge opinion  \
# A     rating-box 2022-05-06  rating-box                 NaN
# AADI  rating-box 2022-11-18         NaN                 NaN
# AAON  rating-box 2022-01-07  rating-box                 NaN
# AAP   rating-box 2022-04-22  rating-box                 NaN
# AAPL  rating-box 2022-10-21  rating-box                 NaN
# ...          ...        ...         ...                 ...
# XOM   rating-box 2022-11-04         NaN                 NaN
# XPEL  rating-box 2022-09-30         NaN                 NaN
# XYL   rating-box 2021-07-09         NaN                 NaN
# ZTS   rating-box 2022-04-08         NaN                 NaN
# ZYXI  rating-box 2022-07-29         NaN                 NaN
#
#      marketEdge opinion since marketEdge since newConstructs  \
# A                         NaT       2016-03-28    rating-box
# AADI                      NaT              NaT    rating-box
# AAON                      NaT       2022-11-10    rating-box
# AAP                       NaT       2020-08-19    rating-box
# AAPL                      NaT       2009-04-13    rating-box
# ...                       ...              ...           ...
# XOM                       NaT              NaT    rating-box
# XPEL                      NaT              NaT    rating-box
# XYL                       NaT              NaT    rating-box
# ZTS                       NaT              NaT    rating-box
# ZYXI                      NaT              NaT    rating-box
#
#      newConstructs since researchTeam researchTeam since   theStreet  \
# A             2022-11-25   rating-box         2022-05-06         NaN
# AADI                 NaT   rating-box                NaT  rating-box
# AAON          2022-11-26   rating-box         2022-01-07         NaN
# AAP           2022-11-26   rating-box         2021-02-05         NaN
# AAPL          2022-11-26   rating-box         2022-10-21         NaN
# ...                  ...          ...                ...         ...
# XOM           2022-11-28   rating-box         2022-08-20  rating-box
# XPEL          2022-11-28   rating-box         2022-09-30  rating-box
# XYL           2022-11-28   rating-box         2021-03-29  rating-box
# ZTS           2022-11-26   rating-box         2021-03-29  rating-box
# ZYXI          2022-11-28   rating-box         2022-07-29  rating-box
#
#      theStreet since
# A                NaT
# AADI             NaT
# AAON             NaT
# AAP              NaT
# AAPL             NaT
# ...              ...
# XOM       2022-01-20
# XPEL      2022-08-18
# XYL       2022-11-02
# ZTS       2015-12-07
# ZYXI      2021-12-21
#
# [928 rows x 104 columns]

# %%
nmr_us.loc['NVDA']
# Out:
# % Above Low                            0.5047
# % Below High                              NaN
# % Held by Institutions                 0.6318
# 52-Wk Range               ['108.13 - 334.12']
# 5yr Avg Return                        0.39695
#                                  ...
# newConstructs since       2022-11-28 00:00:00
# researchTeam                       rating-box
# researchTeam since        2022-08-26 00:00:00
# theStreet                          rating-box
# theStreet since           2022-09-16 00:00:00
# Name: NVDA, Length: 104, dtype: object

# %%
results['fundies']
# Out:
#                                      NVDA
# Price/Earnings (TTM)         7.026312e+01
# Price/Sales (TTM)            1.422556e+01
# Price/Book (MRQ)             1.909639e+01
# Price/Cash Flow (TTM)        5.503350e+01
# 5yr Low                      3.112000e+01
# 5yr High                     3.464700e+02
# 5yr Avg Return               3.931667e-01
# EPS Growth 5yr               4.306999e-01
# Revenue Growth 5yr           3.125022e-01
# Dividend Growth 5yr          5.703080e-02
# Short Int Current Month      3.145168e+07
# Short Int Prev Month         3.287464e+07
# Short Int Pct of Float       1.317360e-02
# Days to Cover                5.608700e-01
# Float                        2.358385e+03
# Shares Outstanding           2.460000e+03
# Institutions Holding Shares  3.635000e+03
# % Held by Institutions       6.324180e-01
# FCF Growth 5yr              -9.436972e-02

# %%
summary = scrape_summary(driver, 'NVDA')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:242: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:247: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:252: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:282: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:286: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:292: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:297: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:303: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_18168\1979482013.py:308: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],

# %%
yearning, yearning_yrly = scrape_earnings(driver, 'NVDA', search_first=False, internet_speed='slow')

# %%
fundies, fundies_yrly = scrape_fundamentals(driver, 'NVDA', search_first=False)

# %%
valuation = scrape_valuation(driver, 'NVDA')

# %%
analysis = scrape_analysts(driver, 'NVDA')

# %%
yearning
# Out:
#                                            NVDA
# Next Earnings Announcement  2023-02-22 00:00:00
# Growth Analysts                            35.0
# Growth 1yr Low Est                    -0.293981
# Growth 1yr High Est                   -0.244851
# Growth 1yr Consensus Est              -0.269416
# Growth 2yr Low Est                     -0.09781
# Growth 2yr High Est                    0.165453
# Growth 2yr Consensus Est               0.033821
# Growth 5yr Low Est                     0.001648
# Growth 5yr High Est                    0.139304
# Growth 5yr Consensus Est               0.070476
# Growth 5yr Actual/Est                  0.391415
# Growth 3yr Historic                    0.375034

# %%
yearning_yrly
# Out:
#                    Earnings Result  Actual  Estimate    Growth  Low Estimate  \
# Year ending 1/2020         Neutral    1.45       NaN       NaN          5.50
# Year ending 1/2021         Neutral    2.50       NaN  0.724138          9.65
# Year ending 1/2022         Neutral    4.44       NaN  0.776000          4.32
# Year ending 1/2023         Neutral     NaN      3.26  0.000000          3.05
# Year ending 1/2024         Neutral     NaN      4.34  0.000000          3.35
#
#                     Low Growth Est  High Estimate  High Growth Est  \
# Year ending 1/2020             NaN           5.72              NaN
# Year ending 1/2021        0.754545          10.31         0.802448
# Year ending 1/2022       -0.552332           4.37        -0.576140
# Year ending 1/2023       -0.293981           3.30        -0.244851
# Year ending 1/2024        0.098361           5.20         0.575758
#
#                     Consensus Estimate  Actual/Estimate  A/E Growth  \
# Year ending 1/2020               5.610             1.45         NaN
# Year ending 1/2021               9.980             2.50    0.724138
# Year ending 1/2022               4.345             4.44    0.776000
# Year ending 1/2023               3.260             3.26   -0.265766
# Year ending 1/2024               4.340             4.34    0.331288
#
#                     Consensus Growth Est
# Year ending 1/2020                   NaN
# Year ending 1/2021              0.778497
# Year ending 1/2022             -0.564236
# Year ending 1/2023             -0.269416
# Year ending 1/2024              0.337059

# %%
analysis
# Out:
#                           NVDA Rating Since
# newConstructs       rating-box   2022-11-22
# researchTeam        rating-box   2022-08-26
# theStreet           rating-box   2022-09-16
# cfra                       NaN   2020-03-28
# ford                rating-box   2022-11-11
# marketEdge opinion         NaN          NaT

# %%
valuation
# Out:
#                                                            NVDA     Industry  \
# Price/Earnings (TTM, GAAP)                         6.515000e+01      20.0800
# Price/Sales (TTM)                                  1.319000e+01       7.0900
# Price/Book (MRQ)                                   1.771000e+01      12.3700
# PEG Ratio (TTM, GAAP)                              3.060000e+00       0.9900
# Gross Profit Margin (TTM)                          5.784000e-01       0.5469
# Operating Profit Margin (TTM)                      2.079000e-01       0.2539
# Net Profit Margin (TTM)                            2.085000e-01       0.2198
# Annual Dividend Yield                              1.000000e-03       0.0150
# Dividend Change %                                  0.000000e+00       0.0694
# Dividend Growth Rate, 3 Years                      1.610000e-02       0.0917
# EPS Growth (MRQ)                                   4.360000e-02       1.0836
# EPS Growth (TTM)                                  -2.742000e-01       0.2031
# Revenue Growth (MRQ)                              -1.153000e-01       0.1513
# Revenue Growth (TTM)                               1.768000e-01       0.2444
# Return On Equity (TTM)                             2.639000e-01       0.3709
# Return On Assets (TTM)                             1.469000e-01       0.1605
# Return On Investment (TTM)                         1.686000e-01       0.1932
# Revenue Per Employee (TTM)                         1.271125e+06  889672.0000
# Total Debt/Total Capital (MRQ)                     3.390000e-01       0.3574
# Change in Debt/Total Capital Quarter over Quarter  0.000000e+00      -0.0002
# Quick Ratio (MRQ)                                  2.740000e+00       2.2300
# Interest Coverage (MRQ)                                     NaN      15.6600
#
#                                                                  Type  \
# Price/Earnings (TTM, GAAP)                                  Valuation
# Price/Sales (TTM)                                           Valuation
# Price/Book (MRQ)                                            Valuation
# PEG Ratio (TTM, GAAP)                                       Valuation
# Gross Profit Margin (TTM)                               Profitability
# Operating Profit Margin (TTM)                           Profitability
# Net Profit Margin (TTM)                                 Profitability
# Annual Dividend Yield                                        Dividend
# Dividend Change %                                            Dividend
# Dividend Growth Rate, 3 Years                                Dividend
# EPS Growth (MRQ)                                          Gowth rates
# EPS Growth (TTM)                                          Gowth rates
# Revenue Growth (MRQ)                                      Gowth rates
# Revenue Growth (TTM)                                      Gowth rates
# Return On Equity (TTM)                                  Effectiveness
# Return On Assets (TTM)                                  Effectiveness
# Return On Investment (TTM)                              Effectiveness
# Revenue Per Employee (TTM)                              Effectiveness
# Total Debt/Total Capital (MRQ)                     Financial strength
# Change in Debt/Total Capital Quarter over Quarter  Financial strength
# Quick Ratio (MRQ)                                  Financial strength
# Interest Coverage (MRQ)                            Financial strength
#
#                                                    Ratio to Industry
# Price/Earnings (TTM, GAAP)                                  3.244522
# Price/Sales (TTM)                                           1.860367
# Price/Book (MRQ)                                            1.431690
# PEG Ratio (TTM, GAAP)                                       3.090909
# Gross Profit Margin (TTM)                                   1.057597
# Operating Profit Margin (TTM)                               0.818826
# Net Profit Margin (TTM)                                     0.948590
# Annual Dividend Yield                                       0.066667
# Dividend Change %                                           0.000000
# Dividend Growth Rate, 3 Years                               0.175573
# EPS Growth (MRQ)                                            0.040236
# EPS Growth (TTM)                                           -1.350074
# Revenue Growth (MRQ)                                       -0.762062
# Revenue Growth (TTM)                                        0.723404
# Return On Equity (TTM)                                      0.711513
# Return On Assets (TTM)                                      0.915265
# Return On Investment (TTM)                                  0.872671
# Revenue Per Employee (TTM)                                  1.428757
# Total Debt/Total Capital (MRQ)                              0.948517
# Change in Debt/Total Capital Quarter over Quarter          -0.000000
# Quick Ratio (MRQ)                                           1.228700
# Interest Coverage (MRQ)                                          NaN

# %%
fundies
# Out:
#                                      NVDA
# Price/Earnings (TTM)         6.515045e+01
# Price/Sales (TTM)            1.319044e+01
# Price/Book (MRQ)             1.770685e+01
# Price/Cash Flow (TTM)        5.102901e+01
# 5yr Low                      3.112000e+01
# 5yr High                     3.464700e+02
# 5yr Avg Return               3.916667e-01
# EPS Growth 5yr               4.306999e-01
# Revenue Growth 5yr           3.125022e-01
# Dividend Growth 5yr          5.703080e-02
# Short Int Current Month      3.145168e+07
# Short Int Prev Month         3.287464e+07
# Short Int Pct of Float       1.317360e-02
# Days to Cover                5.608700e-01
# Float                        2.358385e+03
# Shares Outstanding           2.460000e+03
# Institutions Holding Shares  3.635000e+03
# % Held by Institutions       6.324070e-01
# FCF Growth 5yr              -9.436972e-02

# %%
fundies_yrly
# Out:
#                                   2017    2018    2019    2020    2021  \
# high                             54.34   73.19   60.45  147.27  346.47
# low                              45.15   31.12   31.92   45.17  115.67
# change                         -0.1025 -0.3181  0.8011  1.1872  1.2444
# Date                               NaN     NaN     NaN     NaN     NaN
# Cash & Equivalents                 NaN     NaN     NaN     NaN     NaN
# ...                                ...     ...     ...     ...     ...
# NetCash-BeginBal/RsvdforFutUse     NaN     NaN     NaN     NaN     NaN
# NetCash-EndBal/RsrvforFutUse       NaN     NaN     NaN     NaN     NaN
# Depreciation, Supplemental         NaN     NaN     NaN     NaN     NaN
# Free Cash Flow                     NaN     NaN     NaN     NaN     NaN
# FCF Growth                         NaN     NaN     NaN     NaN     NaN
#
#                                   2022              Q4 2022  \
# high                            307.11                  NaN
# low                             108.13                  NaN
# change                         -0.4621                  NaN
# Date                               NaN  2022-01-30 00:00:00
# Cash & Equivalents                 NaN               1990.0
# ...                                ...                  ...
# NetCash-BeginBal/RsvdforFutUse     NaN                847.0
# NetCash-EndBal/RsrvforFutUse       NaN               1990.0
# Depreciation, Supplemental         NaN               1174.0
# Free Cash Flow                     NaN               8132.0
# FCF Growth                         NaN                  NaN
#
#                                             Q1 2023              Q2 2023  \
# high                                            NaN                  NaN
# low                                             NaN                  NaN
# change                                          NaN                  NaN
# Date                            2022-05-01 00:00:00  2022-07-31 00:00:00
# Cash & Equivalents                           3887.0               3013.0
# ...                                             ...                  ...
# NetCash-BeginBal/RsvdforFutUse               1990.0               1990.0
# NetCash-EndBal/RsrvforFutUse                 3887.0               3013.0
# Depreciation, Supplemental                    334.0                712.0
# Free Cash Flow                               1370.0               2207.0
# FCF Growth                                 -0.83153             0.610949
#
#                                             Q3 2023         Report
# high                                            NaN            NaN
# low                                             NaN            NaN
# change                                          NaN            NaN
# Date                            2022-10-30 00:00:00  Balance Sheet
# Cash & Equivalents                          13143.0  Balance Sheet
# ...                                             ...            ...
# NetCash-BeginBal/RsvdforFutUse               1990.0      Cash Flow
# NetCash-EndBal/RsrvforFutUse                 2800.0      Cash Flow
# Depreciation, Supplemental                   1118.0      Cash Flow
# Free Cash Flow                               2069.0            NaN
# FCF Growth                                -0.062528            NaN
#
# [129 rows x 11 columns]

# %%
search_symbol(driver, 'NVDA')

# %%
# Find main iframe:  
driver.switch_to.default_content()    
iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, "iframe"))
driver.switch_to.frame(iframes[3])

# Switch to Earnings tab:
WebDriverWait(driver,10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/nav/ul/li[4]/a')).click()
time.sleep(1.5)

# Switch to Earnings Analysis (1st sub tab)
WebDriverWait(driver,10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/div[4]/nav/nav/a[1]')).click()
time.sleep(1.5)

# Wait for conditions before making soup
WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Annual Earnings History and Estimates'))
element = driver.find_element(By.XPATH, '//*[@id="main-chart-wrapper"]')
WebDriverWait(driver, 10).until(lambda x: EC.visibility_of_element_located(element))

# Make soup and find container/elements
soup = BeautifulSoup(driver.page_source, 'html.parser')
earn_dict = {}
earnings_dict = {}
contain = soup.find('div', {'data-module-name':'EarningsAnalysisModule'})
header = contain.find('div', {'class':'row contain earnings-data'})
#key = header.find('td', {'class':'label bordered'}).get_text()
earn_dict['Next Earnings Announcement'] = header.find('td', {'class':'value week-of'}).get_text()

# %%
earn_dict
# Out:
# {'Next Earnings Announcement': 'February 22, 2023'}

# %%
header
# Out:
# <div class="row contain earnings-data"><table><thead><tr><th colspan="4">Annual Earnings Met Consensus (Year ending 01/2022)</th><th colspan="2">Next Earnings Announcement</th></tr></thead><tbody><tr><td class="label">Annual <div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "GAAP vs. Non-GAAP Earnings"]}' href="#">Non-GAAP earnings</a><div class="ui-tooltip-content shadow boxshadow ui-open-up ui-position-left click"><h4 class="heading heading-3">GAAP vs. Non-GAAP Earnings</h4><p>TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div><br/>Announced February 16, 2022</td><td class="value">$4.44</td><td class="label">Annual Estimate range<br/>of 35 analysts</td><td class="value">$4.32 to $4.37</td><td class="label bordered">2023 Earnings<br/>will announce</td><td class="value week-of">February 22, 2023</td></tr></tbody></table></div>

# %%
# Get number of analysts reporting on security
analysts = header.find_all('td', {'class':'label'})[1].get_text().split()
for word in analysts:
    # The number of analysts will be the only numerical string
    try:
        earn_dict['Growth Analysts'] = float(word)
    except:
        continue
# Find chart object in container, then bars
chart = contain.find('div', {'id':'main-chart-wrapper'})
bars = chart.find_all('div', {'class':'ui-tooltip'})
for bar in bars:
    text = bar.get_text('|').split('|')
    # text[0] is the year
    year = text[0]
    earnings_dict[year] = {}
    # There is more text when there is a earnings surprise
    if len(text) > 4:
        earnings_dict[year]['Earnings Result'] = text[1]
        earnings_dict[year][text[2].strip('"').strip().strip(':')] = float(text[3].replace('$',''))
        earnings_dict[year][text[4].split(':')[0]] = text[4].split(':')[1].strip()
    else:
        earnings_dict[year]['Earnings Result'] = 'Neutral'
        # Should be a string: 'Actual' or 'Estimate'
        est_string = text[1].strip('"').strip().strip(':')
        # The actual consensus estimate
        est = float(text[2].replace('$',''))
        earnings_dict[year][est_string] = est
        # Should be a string: 'Estimate range'
        est_range_string = text[3].split(':')[0]
        # The estimate range as a string
        est_range = text[3].split(':')[1].strip()
        # Convert to 
        earnings_dict[year][est_range_string] = est_range

# %%
chart
# Out:
# <div class="col-xs-12 chart-wrapper currently-loading" data-chartinputs='{"type":"earnings","wsodissue":"218647","period":"ann","fyEndMonth":1,"isReport":false}' data-loading="1" data-symbol="NVDA" id="main-chart-wrapper"><img src="/grid/wwws/research/uploadhandler/z2d997d0az62481e728a3d4ce38ca05491d2bd3fcb.gif"/><div class="ui-tooltip" style="position: absolute; top: 135px; left: 64px; height: 20px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 20px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-left"><header><h3>Year ending 1/2020</h3></header><p>Actual: <strong>$1.45</strong></p><p>Estimate range: $5.50 to $5.72</p></div><div class="ui-arrow"></div></div><div class="ui-tooltip" style="position: absolute; top: 121px; left: 254px; height: 34px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 34px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-center"><header><h3>Year ending 1/2021</h3></header><p>Actual: <strong>$2.50</strong></p><p>Estimate range: $9.65 to $10.31</p></div><div class="ui-arrow"></div></div><div class="ui-tooltip" style="position: absolute; top: 94px; left: 444px; height: 61px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 61px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-center"><header><h3>Year ending 1/2022</h3></header><p>Actual: <strong>$4.44</strong></p><p>Estimate range: $4.32 to $4.37</p></div><div class="ui-arrow"></div></div><div class="ui-tooltip" style="position: absolute; top: 111px; left: 634px; height: 44px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 44px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-center"><header><h3>Year ending 1/2023</h3></header><p>Estimate: <strong>$3.26</strong></p><p>Estimate range: $3.05 to $3.30</p></div><div class="ui-arrow"></div></div><div class="ui-tooltip" style="position: absolute; top: 96px; left: 824px; height: 59px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 59px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-right"><header><h3>Year ending 1/2024</h3></header><p>Estimate: <strong>$4.34</strong></p><p>Estimate range: $3.35 to $5.20</p></div><div class="ui-arrow"></div></div></div>

# %%
bars
# Out:
# [<div class="ui-tooltip" style="position: absolute; top: 135px; left: 64px; height: 20px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 20px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-left"><header><h3>Year ending 1/2020</h3></header><p>Actual: <strong>$1.45</strong></p><p>Estimate range: $5.50 to $5.72</p></div><div class="ui-arrow"></div></div>,
#  <div class="ui-tooltip" style="position: absolute; top: 121px; left: 254px; height: 34px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 34px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-center"><header><h3>Year ending 1/2021</h3></header><p>Actual: <strong>$2.50</strong></p><p>Estimate range: $9.65 to $10.31</p></div><div class="ui-arrow"></div></div>,
#  <div class="ui-tooltip" style="position: absolute; top: 94px; left: 444px; height: 61px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 61px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-center"><header><h3>Year ending 1/2022</h3></header><p>Actual: <strong>$4.44</strong></p><p>Estimate range: $4.32 to $4.37</p></div><div class="ui-arrow"></div></div>,
#  <div class="ui-tooltip" style="position: absolute; top: 111px; left: 634px; height: 44px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 44px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-center"><header><h3>Year ending 1/2023</h3></header><p>Estimate: <strong>$3.26</strong></p><p>Estimate range: $3.05 to $3.30</p></div><div class="ui-arrow"></div></div>,
#  <div class="ui-tooltip" style="position: absolute; top: 96px; left: 824px; height: 59px; width: 62px;"><div class="earnings-chart-tooltip ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" style="position: absolute; height: 59px; width: 62px;"></div><div class="ui-tooltip-content shadow ui-open-up ui-position-right"><header><h3>Year ending 1/2024</h3></header><p>Estimate: <strong>$4.34</strong></p><p>Estimate range: $3.35 to $5.20</p></div><div class="ui-arrow"></div></div>]

# %%
earn_dict
# Out:
# {'Next Earnings Announcement': 'February 22, 2023', 'Growth Analysts': 35.0}

# %%
earnings_dict
# Out:
# {}

# %%
# Create df and all useful columns
earnings_yrly = pd.DataFrame.from_dict(earnings_dict, orient='index')
earnings_yrly['Growth'] = earnings_yrly['Actual'].pct_change()
earnings_yrly['Low Estimate'] = earnings_yrly['Estimate range'].map(lambda x: float(x.split()[0].replace('$','')), na_action='ignore')
earnings_yrly['Low Growth Est'] = earnings_yrly['Low Estimate'].pct_change()
earnings_yrly['High Estimate'] = earnings_yrly['Estimate range'].map(lambda x: float(x.split()[2].replace('$','')), na_action='ignore')
earnings_yrly['High Growth Est'] = earnings_yrly['High Estimate'].pct_change()
# Take average of high and low for years where 'Estimate' not available
earnings_yrly['Consensus Estimate'] = (earnings_yrly['High Estimate'] + earnings_yrly['Low Estimate']) / 2
# Supercede these values where consensus estimates are available
idx_to_change = earnings_yrly[earnings_yrly['Estimate'].notnull()].index
earnings_yrly.loc[idx_to_change, 'Consensus Estimate'] = earnings_yrly.loc[idx_to_change, 'Estimate']
# Make new column that contains the actuals and consensus estimates
earnings_yrly['Actual/Estimate'] = earnings_yrly['Actual']
earnings_yrly.loc[idx_to_change, 'Actual/Estimate'] = earnings_yrly.loc[idx_to_change, 'Estimate']
earnings_yrly['A/E Growth'] = earnings_yrly['Actual/Estimate'].pct_change()

if 'Consensus estimate' in earnings_yrly.columns:
    # Sometimes ranges aren't given, and Consensus estimate given instead, fill holes caused
    earnings_yrly['Consensus Estimate'].fillna(earnings_yrly[earnings_yrly['Consensus estimate'].notnull()]['Consensus estimate'].map(lambda x: float(x.replace('$',''))), inplace=True)
    earnings_yrly.drop(columns=['Consensus estimate'], inplace=True)
earnings_yrly.drop(columns=['Estimate range'], inplace=True)
earnings_yrly['Consensus Growth Est'] = (earnings_yrly['High Growth Est']+earnings_yrly['Low Growth Est']) / 2

low_1yr_growth_est = earnings_yrly.iloc[-2,:]['Low Growth Est']
high_1yr_growth_est = earnings_yrly.iloc[-2,:]['High Growth Est']
cons_1yr_growth_est = earnings_yrly.iloc[-2,:]['Consensus Growth Est']
growth_2yr_low_est = earnings_yrly.iloc[-2:]['Low Growth Est'].mean()
growth_2yr_high_est = earnings_yrly.iloc[-2:]['High Growth Est'].mean()
growth_2yr_cons_est = (growth_2yr_low_est + growth_2yr_high_est) / 2
earn_dict['Growth 1yr Low Est'] = low_1yr_growth_est
earn_dict['Growth 1yr High Est'] = high_1yr_growth_est
earn_dict['Growth 1yr Consensus Est'] = cons_1yr_growth_est
earn_dict['Growth 2yr Low Est'] = growth_2yr_low_est
earn_dict['Growth 2yr High Est'] = growth_2yr_high_est
earn_dict['Growth 2yr Consensus Est'] = growth_2yr_cons_est
earn_dict['Growth 5yr Low Est'] = earnings_yrly['Low Growth Est'].mean()
earn_dict['Growth 5yr High Est'] = earnings_yrly['High Growth Est'].mean()
earn_dict['Growth 5yr Consensus Est'] = earnings_yrly['Consensus Growth Est'].mean()
earn_dict['Growth 5yr Actual/Est'] = earnings_yrly['A/E Growth'].mean()
earn_dict['Growth 3yr Historic'] = earnings_yrly['Growth'].mean()

earn_df = pd.DataFrame.from_dict(earn_dict, orient='index', columns=['NVDA'])
earn_df['NVDA'] = earn_df['NVDA'].map(clean)

# %%
earnings_dict
# Out:
# {'Year ending 1/2020': {'Earnings Result': 'Neutral',
#   'Actual': 1.45,
#   'Estimate range': '$5.50 to $5.72'},
#  'Year ending 1/2021': {'Earnings Result': 'Neutral',
#   'Actual': 2.5,
#   'Estimate range': '$9.65 to $10.31'},
#  'Year ending 1/2022': {'Earnings Result': 'Neutral',
#   'Actual': 4.44,
#   'Estimate range': '$4.32 to $4.37'},
#  'Year ending 1/2023': {'Earnings Result': 'Neutral',
#   'Estimate': 3.26,
#   'Estimate range': '$3.05 to $3.30'},
#  'Year ending 1/2024': {'Earnings Result': 'Neutral',
#   'Estimate': 4.34,
#   'Estimate range': '$3.35 to $5.20'}}

# %%
earnings_yrly
# Out:
#                    Earnings Result  Actual  Estimate    Growth  Low Estimate  \
# Year ending 1/2020         Neutral    1.45       NaN       NaN          5.50
# Year ending 1/2021         Neutral    2.50       NaN  0.724138          9.65
# Year ending 1/2022         Neutral    4.44       NaN  0.776000          4.32
# Year ending 1/2023         Neutral     NaN      3.26  0.000000          3.05
# Year ending 1/2024         Neutral     NaN      4.34  0.000000          3.35
#
#                     Low Growth Est  High Estimate  High Growth Est  \
# Year ending 1/2020             NaN           5.72              NaN
# Year ending 1/2021        0.754545          10.31         0.802448
# Year ending 1/2022       -0.552332           4.37        -0.576140
# Year ending 1/2023       -0.293981           3.30        -0.244851
# Year ending 1/2024        0.098361           5.20         0.575758
#
#                     Consensus Estimate  Actual/Estimate  A/E Growth  \
# Year ending 1/2020               5.610             1.45         NaN
# Year ending 1/2021               9.980             2.50    0.724138
# Year ending 1/2022               4.345             4.44    0.776000
# Year ending 1/2023               3.260             3.26   -0.265766
# Year ending 1/2024               4.340             4.34    0.331288
#
#                     Consensus Growth Est
# Year ending 1/2020                   NaN
# Year ending 1/2021              0.778497
# Year ending 1/2022             -0.564236
# Year ending 1/2023             -0.269416
# Year ending 1/2024              0.337059

# %%
login_url = 'https://invest.ameritrade.com/grid/p/login'
driver = webdriver.Chrome()

# %%
tda_login = get_keys('tda_keys.json')

try:
    driver.get(login_url)
except:
    raise ValueError('Caanot find Login button')
else:
    assert "TD Ameritrade Login" in driver.title
    WebDriverWait(driver, 10).until(lambda x: x.find_element(By.CSS_SELECTOR, 'button.cafeLoginButton')).click()
    username = WebDriverWait(driver, 10).until(lambda x: x.find_element(By.ID, 'username0'))
    username.send_keys(tda_login['user'])
    password = WebDriverWait(driver, 10).until(lambda x: x.find_element(By.ID, "password1"))
    password.send_keys(tda_login['pass'])    
    try:
        driver.find_element(By.CSS_SELECTOR, 'input#accept.accept.button').click()
    except:
        raise ValueError("Login fails.")
    else:
        try:
            WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Use desktop website'))
            time.sleep(3)
            button = WebDriverWait(driver, 10).until(lambda x: x.find_element(By.XPATH, value='//*[@id="app"]/div/div[2]/footer/div/ul/li[1]/button'))
            button.click()
            time.sleep(3)
            home_url = driver.current_url
            reduce_tabs(driver)
        except:
            driver.switch_to.default_content()

# %%
driver.switch_to.default_content()
search = driver.find_element(By.NAME, "search")
kind = 'search'

# %%
search.send_keys('NVDA')
if kind == 'symbol':
    driver.find_element(By.XPATH, '//*[@id="layout-full"]/div[1]/div/div[1]/div/a').click()
elif kind == 'search':
    driver.find_element(By.ID, 'searchIcon').click()
time.sleep(4)

# %%
# Find main iframe
driver.switch_to.default_content()
iframes = WebDriverWait(driver, 10).until(lambda x: x.find_elements(By.TAG_NAME, 'iframe'))
driver.switch_to.frame(iframes[3])

# %%
 # Switch to Summary tab
WebDriverWait(driver, 10).until(lambda x: EC.text_to_be_present_in_element(x, 'Summary'))
WebDriverWait(driver, 10).until(lambda x: x.find_element(By.XPATH, '//*[@id="layout-full"]/nav/ul/li[1]/a')).click()

# %%
# Wait for conditions to be met before making soup
element = driver.find_element(By.XPATH, '//*[@id="stock-summarymodule"]/div/div/div[2]/div')
WebDriverWait(driver, 10).until(lambda x: EC.visibility_of_element_located(element))
# Add extra time for data to load
time.sleep(1)

# %%
# Make soup and find elements
soup = BeautifulSoup(driver.page_source, 'html.parser')
dts = soup.find_all('dt')

# Set flag which will be made false if no dividend is given
dividend_given = True
texts = []
for dt in dts:
    try:
        texts.append(dt.get_text('|'))        
    except:
        print("error")
        continue

dds = soup.find_all('dd')
values = []
for dd in dds:
    try:
        values.append(dd.get_text('|'))        
    except:
        print("error")
        continue

fields = [x.split('|')[0] for x in texts]
alt_info = [x.split('|')[1:] for x in texts]

# %%
# Make dataframe and fix row names
data_dict = dict(zip(fields,zip(alt_info,values)))
temp = pd.DataFrame.from_dict(data_dict, orient='index')
temp.loc['Volume', 1] = temp.loc['Volume', 0][0].strip()
temp.rename(index={'Volume:':'Volume 10-day Avg',
                        'Volume':'Volume Past Day',
                        '10-day average volume:':'Volume',
                        'Score:':'New Constructs Score'
                    }, inplace=True)
temp.loc['52-Wk Range', 1] = temp.loc['52-Wk Range', 0]
price_feat = 'Closing Price'

# %%
temp
# Out:
#                                                                         0  \
# Closing Price                                                          []
# Day's Change                                                           []
# Bid                                                                    []
# Ask                                                                    []
# B/A Size                                                               []
# Day's High                                                             []
# Day's Low                                                              []
# Volume Past Day         [(Below Average), Volume:, 49,207,165, 10-day ...
# Volume 10-day Avg                                                      []
# Volume                                                                 []
# Prev Close                                                             []
# Today's Open                                                           []
# Day's Range                                                            []
# Avg Vol (10-day)                                                       []
# Last (time)                                                            []
# Last (size)                                                            []
# 52-Wk Range                                             [108.13 - 346.47]
# % Above Low             [% Above Low, The current share price compared...
# Historical Volatility   [Historical Volatility, The volatility of a st...
# Market Cap                                                             []
# Shares Outstanding                                                     []
# EPS (TTM, GAAP)         [EPS (TTM, GAAP), GAAP EPS (TTM) refers to a c...
# P/E Ratio (TTM, GAAP)   [P/E Ratio (TTM, GAAP), GAAP P/E is a relative...
# Annual Dividend/Yield   [Annual Dividend/Yield, Annual Dividend is cal...
# Ex-dividend Date                                                       []
# Dividend Pay Date                                                      []
# Beta                    [Beta, The measure of a security's volatility ...
# % Held by Institutions  [% Held by Institutions, Percentage of outstan...
# Short Interest          [Short Interest, The number of shares of a sec...
# Market Edge Opinion:                                                   []
# New Constructs Score                                                   []
#
#                                         1
# Closing Price                     $154.09
# Day's Change             -2.68| |(-1.71%)
# Bid                                153.57
# Ask                                153.60
# B/A Size                          500x900
# Day's High                         160.02
# Day's Low                          151.20
# Volume Past Day           (Below Average)
# Volume 10-day Avg              57,771,720
# Volume                         49,207,165
# Prev Close                         156.77
# Today's Open                       159.66
# Day's Range                 151.20-160.02
# Avg Vol (10-day)                    57.8M
# Last (time)             4:00p ET 11/18/22
# Last (size)                             5
# 52-Wk Range             [108.13 - 346.47]
# % Above Low                        42.50%
# Historical Volatility               63.6%
# Market Cap                         383.7B
# Shares Outstanding                   2.5B
# EPS (TTM, GAAP)                      2.35
# P/E Ratio (TTM, GAAP)              65.54x
# Annual Dividend/Yield         $0.16/0.10%
# Ex-dividend Date                 11/30/22
# Dividend Pay Date                12/22/22
# Beta                                  1.7
# % Held by Institutions              62.48
# Short Interest                       1.32
# Market Edge Opinion:                 Long
# New Constructs Score                    0

# %%
temp
# Out:
#                                                                         0  \
# Closing Price                                                          []
# Day's Change                                                           []
# Bid                                                                    []
# Ask                                                                    []
# B/A Size                                                               []
# Day's High                                                             []
# Day's Low                                                              []
# Volume                  [(Below Average), Volume:, 49,207,165, 10-day ...
# Volume:                                                                []
# 10-day average volume:                                                 []
# Prev Close                                                             []
# Today's Open                                                           []
# Day's Range                                                            []
# Avg Vol (10-day)                                                       []
# Last (time)                                                            []
# Last (size)                                                            []
# 52-Wk Range                                             [108.13 - 346.47]
# % Above Low             [% Above Low, The current share price compared...
# Historical Volatility   [Historical Volatility, The volatility of a st...
# Market Cap                                                             []
# Shares Outstanding                                                     []
# EPS (TTM, GAAP)         [EPS (TTM, GAAP), GAAP EPS (TTM) refers to a c...
# P/E Ratio (TTM, GAAP)   [P/E Ratio (TTM, GAAP), GAAP P/E is a relative...
# Annual Dividend/Yield   [Annual Dividend/Yield, Annual Dividend is cal...
# Ex-dividend Date                                                       []
# Dividend Pay Date                                                      []
# Beta                    [Beta, The measure of a security's volatility ...
# % Held by Institutions  [% Held by Institutions, Percentage of outstan...
# Short Interest          [Short Interest, The number of shares of a sec...
# Market Edge Opinion:                                                   []
# Score:                                                                 []
#
#                                         1
# Closing Price                     $154.09
# Day's Change             -2.68| |(-1.71%)
# Bid                                153.57
# Ask                                153.60
# B/A Size                          500x900
# Day's High                         160.02
# Day's Low                          151.20
# Volume                         49,207,165
# Volume:                        57,771,720
# 10-day average volume:         49,207,165
# Prev Close                         156.77
# Today's Open                       159.66
# Day's Range                 151.20-160.02
# Avg Vol (10-day)                    57.8M
# Last (time)             4:00p ET 11/18/22
# Last (size)                             5
# 52-Wk Range                      Low|High
# % Above Low                        42.50%
# Historical Volatility               63.6%
# Market Cap                         383.7B
# Shares Outstanding                   2.5B
# EPS (TTM, GAAP)                      2.35
# P/E Ratio (TTM, GAAP)              65.54x
# Annual Dividend/Yield         $0.16/0.10%
# Ex-dividend Date                 11/30/22
# Dividend Pay Date                12/22/22
# Beta                                  1.7
# % Held by Institutions              62.48
# Short Interest                       1.32
# Market Edge Opinion:                 Long
# Score:                                  0

# %%
if price_feat not in temp.index:
    if 'Price' in temp.index:
        price_feat = 'Price'

# Cleaning data
if temp.loc["B/A Size",1] == '--': 
    temp = temp.append(pd.Series([[],
                                np.NaN
                                ],
                                name="Bid Size"),
                    )
    temp = temp.append(pd.Series([[],
                                np.NaN
                                ],
                                name="Ask Size"),
                    )
    temp = temp.append(pd.Series([[],
                                np.NaN
                                ],
                                name="B/A Ratio"),
                    )
else:
    temp = temp.append(pd.Series([[],
                                float(temp.loc['B/A Size',1].split('x')[0])
                                ],
                                name="Bid Size"),
                    )
    temp = temp.append(pd.Series([[],
                                float(temp.loc['B/A Size',1].split('x')[1])
                                ],
                                name="Ask Size"),
                    )
    temp = temp.append(pd.Series([[],
                                float(temp.loc['B/A Size',1].split('x')[0])
                                        /float(temp.loc['B/A Size',1].split('x')[1])
                                ],
                                name="B/A Ratio"),
                )  
if temp.loc["Day's Range",1] == '--':
    temp = temp.append(pd.Series([[],
                                np.NaN,
                                ],
                                name="Day Change $"
                            ),
                    )
    temp = temp.append(pd.Series([[],
                                np.NaN
                                ],
                                name="Day Change %"
                            ),
                    )
    temp = temp.append(pd.Series([[],
                                np.NaN
                                ],
                            name="Day Low"),
                    )
    temp = temp.append(pd.Series([[],
                                np.NaN
                                ],
                            name="Day High"),
                    )
else:
    temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
                                name="Day Change $"
                            ),
                    )
    temp = temp.append(pd.Series([[],
                                float(temp.loc["Day's Change",1].split('|')[2].strip('%)').strip('()'))/100
                                ],
                                name="Day Change %"
                            ),
                    )
    temp = temp.append(pd.Series([[],
                                float(temp.loc["Day's Range",1].split('-')[0].strip('|').replace(',',''))
                                ],
                            name="Day Low"),
                    )
    temp = temp.append(pd.Series([[],
                                float(temp.loc["Day's Range",1].split('-')[1].strip('|').replace(',',''))
                                ],
                            name="Day High"),
                    )
if temp.loc["Annual Dividend/Yield",1] != 'No dividend':
    temp = temp.append(pd.Series([[],
                                float(temp.loc["Annual Dividend/Yield",1].split('/')[0].strip('$'))
                                ],
                            name="Annual Dividend $"))

    temp = temp.append(pd.Series([[],
                                float(temp.loc["Annual Dividend/Yield",1].split('/')[1].strip('%'))/100
                                ],
                            name="Annual Dividend %"))
else:
    dividend_given = False
    temp = temp.append(pd.Series([[],
                                np.NaN
                                ],
                            name="Annual Dividend $"))
    temp = temp.append(pd.Series([[],
                                np.NaN
                                ],
                            name="Annual Dividend %"))
temp.rename(columns={1:'NVDA'}, inplace = True)
drop = ["Day's Change", 
        "Day's Range",
        "Day's High",
        "Day's Low",
        "Avg Vol (10-day)", 
        #"52-Wk Range", 
        "Annual Dividend/Yield",
        "New Constructs Score"
        ]

# Drop feature description column if flag is False (default)
if False == False:
    temp.drop(index=drop, columns=[0], inplace=True, errors='ignore')

# Clean data
temp = temp.T
# Only one of these columns will be present:
try:
    temp['% Below High'] = temp['% Below High'].map(lambda x: float(x.strip('%'))/100, na_action='ignore')
except:
    temp['% Above Low'] = temp['% Above Low'].map(lambda x: clean(x), na_action='ignore')

temp['% Held by Institutions'] = temp['% Held by Institutions'].map(lambda x: clean(x)/100, na_action='ignore')
temp['Short Interest'] = temp['Short Interest'].map(lambda x: clean(x)/100, na_action='ignore')
# Set list of columns for cleaing
try_to_clean = ['Prev Close',
                'Ask close',
                'Bid close',
                'Beta',
                'Ask',
                'Bid',
                'EPS (TTM, GAAP)',
                'Last Trade',
                'Last (size)',
                price_feat,
                'Historical Volatility',
                'P/E Ratio (TTM, GAAP)',
                "Today's Open",
                'Volume',
                'Volume 10-day Avg']
# Clean columns
for col in try_to_clean:
    try:
        temp[col] = temp[col].map(lambda x: clean(x), na_action='ignore')
    except:
        pass

# Convert date info to datetime if it exists
if dividend_given:
    try:
        temp['Ex-dividend'] = pd.to_datetime(temp['Ex-dividend Date'], infer_datetime_format=True)
    except:
        temp['Ex-dividend'] = pd.to_datetime(temp['Ex-dividend'], infer_datetime_format=True)
    temp['Dividend Pay Date'] = pd.to_datetime(temp['Dividend Pay Date'], infer_datetime_format=True)

# Try to force any remaining numbers to floats:
temp = temp.astype('float64', errors='ignore')
temp = temp.T   
temp.sort_index(inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],float(temp.loc["Day's Change",1].split('|')[0].strip('|'))],
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:67: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:73: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:84: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],
# C:\Users\USER\AppData\Local\Temp\ipykernel_13904\442169927.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp = temp.append(pd.Series([[],

# %%
temp
# Out:
#                                        NVDA
# % Above Low                           0.425
# % Held by Institutions               0.6248
# 52-Wk Range               [108.13 - 346.47]
# Annual Dividend $                      0.16
# Annual Dividend %                     0.001
# Ask                                   153.6
# Ask Size                              900.0
# B/A Ratio                          0.555556
# B/A Size                            500x900
# Beta                                    1.7
# Bid                                  153.57
# Bid Size                              500.0
# Closing Price                        154.09
# Day Change $                          -2.68
# Day Change %                        -0.0171
# Day High                             160.02
# Day Low                               151.2
# Dividend Pay Date       2022-12-22 00:00:00
# EPS (TTM, GAAP)                        2.35
# Ex-dividend             2022-11-30 00:00:00
# Ex-dividend Date                   11/30/22
# Historical Volatility                 0.636
# Last (size)                             5.0
# Last (time)               4:00p ET 11/18/22
# Market Cap                           383.7B
# Market Edge Opinion:                   Long
# P/E Ratio (TTM, GAAP)                 65.54
# Prev Close                           156.77
# Shares Outstanding                     2.5B
# Short Interest                       0.0132
# Today's Open                         159.66
# Volume                           49207165.0
# Volume 10-day Avg                57771720.0
# Volume Past Day             (Below Average)

# %%
data_dict
# Out:
# {'Closing Price': ([], '$154.09'),
#  "Day's Change": ([], '-2.68| |(-1.71%)'),
#  'Bid': ([], '153.57'),
#  'Ask': ([], '153.60'),
#  'B/A Size': ([], '500x900'),
#  "Day's High": ([], '160.02'),
#  "Day's Low": ([], '151.20'),
#  'Volume': (['(Below Average)',
#    'Volume:',
#    '49,207,165',
#    '10-day average volume:',
#    '57,771,720'],
#   '49,207,165'),
#  'Volume:': ([], '57,771,720'),
#  '10-day average volume:': ([], '49,207,165'),
#  'Prev Close': ([], '156.77'),
#  "Today's Open": ([], '159.66'),
#  "Day's Range": ([], '151.20-160.02'),
#  'Avg Vol (10-day)': ([], '57.8M'),
#  'Last (time)': ([], '4:00p ET 11/18/22'),
#  'Last (size)': ([], '5'),
#  '52-Wk Range': (['108.13 - 346.47'], 'Low|High'),
#  '% Above Low': (['% Above Low',
#    'The current share price compared to the 52-week low.'],
#   '42.50%'),
#  'Historical Volatility': (['Historical Volatility',
#    "The volatility of a stock over a given time period. It is calculated by determining the average standard deviation from the average price of the stock over one month or 21 business days. Historical volatility can be compared with implied volatility to determine if a stock's options are over- or undervalued."],
#   '63.6%'),
#  'Market Cap': ([], '383.7B'),
#  'Shares Outstanding': ([], '2.5B'),
#  'EPS (TTM, GAAP)': (['EPS (TTM, GAAP)',
#    "GAAP EPS (TTM) refers to a company's earnings per share (EPS) for the trailing twelve-month (TTM) period. EPS is calculated by dividing the adjusted income available to common stockholders for the trailing twelve months by the trailing twelve-month diluted weighted average shares outstanding.",
#    'GAAP vs. Non-GAAP Earnings',
#    'TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.'],
#   '2.35'),
#  'P/E Ratio (TTM, GAAP)': (['P/E Ratio (TTM, GAAP)',
#    'GAAP P/E is a relative valuation measure used to determine if a stock is expensive in relation to its peers. It is calculated by dividing the current stock price by the sum of the Diluted Earnings Per Share from continuing operations BEFORE Extraordinary Items and Accounting Changes over the last reported 12 months.',
#    'GAAP vs. Non-GAAP Earnings',
#    'TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.'],
#   '65.54x'),
#  'Annual Dividend/Yield': (['Annual Dividend/Yield',
#    'Annual Dividend is calculated by multiplying the announced next regular dividend amount times the annual payment frequency. If no new dividend has been announced, the most recent dividend is used. If dividend payments are inconsistent, as with many ADRs, the annual dividend is calculated by totaling the regular dividends paid over the trailing 12 months. Annual Dividend/yield calculations do not guarantee or imply future payment of dividends.'],
#   '$0.16/0.10%'),
#  'Ex-dividend Date': ([], '11/30/22'),
#  'Dividend Pay Date': ([], '12/22/22'),
#  'Beta': (['Beta',
#    "The measure of a security's volatility in relation to the S&P 500. Beta less than 1 means the security's price or NAV has been less volatile than the market. Beta greater than 1 means the security's price or NAV has been more volatile than the market."],
#   '1.7'),
#  '% Held by Institutions': (['% Held by Institutions',
#    'Percentage of outstanding shares that are owned by institutional investors. Calculated from current quarterly filing as of today.'],
#   '62.48'),
#  'Short Interest': (['Short Interest',
#    'The number of shares of a security that have been sold short by investors. It is typically expressed as a percentage of the total number of shares outstanding and is reported on a monthly basis.',
#    ' ',
#    '(% of float 10/31/22)'],
#   '1.32'),
#  'Market Edge Opinion:': ([], 'Long'),
#  'Score:': ([], '0')}

# %%
alt_info
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['(Below Average)',
#   'Volume:',
#   '49,207,165',
#   '10-day average volume:',
#   '57,771,720'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['108.13 - 346.47'],
#  ['% Above Low', 'The current share price compared to the 52-week low.'],
#  ['Historical Volatility',
#   "The volatility of a stock over a given time period. It is calculated by determining the average standard deviation from the average price of the stock over one month or 21 business days. Historical volatility can be compared with implied volatility to determine if a stock's options are over- or undervalued."],
#  [],
#  [],
#  ['EPS (TTM, GAAP)',
#   "GAAP EPS (TTM) refers to a company's earnings per share (EPS) for the trailing twelve-month (TTM) period. EPS is calculated by dividing the adjusted income available to common stockholders for the trailing twelve months by the trailing twelve-month diluted weighted average shares outstanding.",
#   'GAAP vs. Non-GAAP Earnings',
#   'TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.'],
#  ['P/E Ratio (TTM, GAAP)',
#   'GAAP P/E is a relative valuation measure used to determine if a stock is expensive in relation to its peers. It is calculated by dividing the current stock price by the sum of the Diluted Earnings Per Share from continuing operations BEFORE Extraordinary Items and Accounting Changes over the last reported 12 months.',
#   'GAAP vs. Non-GAAP Earnings',
#   'TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.'],
#  ['Annual Dividend/Yield',
#   'Annual Dividend is calculated by multiplying the announced next regular dividend amount times the annual payment frequency. If no new dividend has been announced, the most recent dividend is used. If dividend payments are inconsistent, as with many ADRs, the annual dividend is calculated by totaling the regular dividends paid over the trailing 12 months. Annual Dividend/yield calculations do not guarantee or imply future payment of dividends.'],
#  [],
#  [],
#  ['Beta',
#   "The measure of a security's volatility in relation to the S&P 500. Beta less than 1 means the security's price or NAV has been less volatile than the market. Beta greater than 1 means the security's price or NAV has been more volatile than the market."],
#  ['% Held by Institutions',
#   'Percentage of outstanding shares that are owned by institutional investors. Calculated from current quarterly filing as of today.'],
#  ['Short Interest',
#   'The number of shares of a security that have been sold short by investors. It is typically expressed as a percentage of the total number of shares outstanding and is reported on a monthly basis.',
#   ' ',
#   '(% of float 10/31/22)'],
#  [],
#  []]

# %%
fields
# Out:
# ['Closing Price',
#  "Day's Change",
#  'Bid',
#  'Ask',
#  'B/A Size',
#  "Day's High",
#  "Day's Low",
#  'Volume',
#  'Volume:',
#  '10-day average volume:',
#  'Prev Close',
#  "Today's Open",
#  "Day's Range",
#  'Avg Vol (10-day)',
#  'Last (time)',
#  'Last (size)',
#  '52-Wk Range',
#  '% Above Low',
#  'Historical Volatility',
#  'Market Cap',
#  'Shares Outstanding',
#  'EPS (TTM, GAAP)',
#  'P/E Ratio (TTM, GAAP)',
#  'Annual Dividend/Yield',
#  'Ex-dividend Date',
#  'Dividend Pay Date',
#  'Beta',
#  '% Held by Institutions',
#  'Short Interest',
#  'Market Edge Opinion:',
#  'Score:']

# %%
dds
# Out:
# [<dd>$154.09</dd>,
#  <dd class="market-hours-change" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["general", "smart text", "days change", "open"]}'><div class="ui-price-change neg"><div class="iconWrapper large floated"><div class="icon icon-arrow-negative"></div></div><span class="price-change">-2.68</span><span class="percent-change"> <span class="neg">(-1.71%)</span></span></div></dd>,
#  <dd><a data-sitevendortrack='{"actionName": "actionClick", "details": ["bid"]}' href="https://invest.ameritrade.com/cgi-bin/apps/u/ThirdPartyUrlLauncher/new?target=bidBttn&amp;param=NVDA&amp;param2=153.57" target="vendorLinks">153.57</a></dd>,
#  <dd><a data-sitevendortrack='{"actionName": "actionClick", "details": ["ask"]}' href="https://invest.ameritrade.com/cgi-bin/apps/u/ThirdPartyUrlLauncher/new?target=askBttn&amp;param=NVDA&amp;param2=153.6" target="vendorLinks">153.60</a></dd>,
#  <dd>500x900</dd>,
#  <dd>160.02</dd>,
#  <dd>151.20</dd>,
#  <dd>49,207,165</dd>,
#  <dd>57,771,720</dd>,
#  <dd>49,207,165</dd>,
#  <dd>156.77</dd>,
#  <dd>159.66</dd>,
#  <dd>151.20-160.02</dd>,
#  <dd>57.8M</dd>,
#  <dd>4:00p ET 11/18/22</dd>,
#  <dd>5</dd>,
#  <dd class="rangeGraphic"><span>Low</span>High<br/><div class="scale-graphic" data-value='{"direction":"down","symbol":"NVDA","callback":"rangeGraphicHover","displayName":"NVIDIA Corp","displayTitle":"52-Week Range","high":"346.47","low":"108.13","highDate":"11/22/21","lowDate":"10/13/22","trackingName":null}' tooltip="tooltip"><div class="scale-point" style="left: calc(19.283376688764% - 4.5px);"></div></div></dd>,
#  <dd>42.50%</dd>,
#  <dd>63.6%</dd>,
#  <dd>383.7B</dd>,
#  <dd>2.5B</dd>,
#  <dd>2.35</dd>,
#  <dd>65.54x</dd>,
#  <dd>$0.16/0.10%</dd>,
#  <dd>11/30/22</dd>,
#  <dd>12/22/22</dd>,
#  <dd>1.7</dd>,
#  <dd>62.48</dd>,
#  <dd>1.32</dd>,
#  <dd>Long</dd>,
#  <dd><span class="neu">0</span></dd>]

# %%
texts
# Out:
# ['Closing Price',
#  "Day's Change",
#  'Bid',
#  'Ask',
#  'B/A Size',
#  "Day's High",
#  "Day's Low",
#  'Volume|(Below Average)|Volume:|49,207,165|10-day average volume:|57,771,720',
#  'Volume:',
#  '10-day average volume:',
#  'Prev Close',
#  "Today's Open",
#  "Day's Range",
#  'Avg Vol (10-day)',
#  'Last (time)',
#  'Last (size)',
#  '52-Wk Range|108.13 - 346.47',
#  '% Above Low|% Above Low|The current share price compared to the 52-week low.',
#  "Historical Volatility|Historical Volatility|The volatility of a stock over a given time period. It is calculated by determining the average standard deviation from the average price of the stock over one month or 21 business days. Historical volatility can be compared with implied volatility to determine if a stock's options are over- or undervalued.",
#  'Market Cap',
#  'Shares Outstanding',
#  "EPS (TTM, GAAP)|EPS (TTM, GAAP)|GAAP EPS (TTM) refers to a company's earnings per share (EPS) for the trailing twelve-month (TTM) period. EPS is calculated by dividing the adjusted income available to common stockholders for the trailing twelve months by the trailing twelve-month diluted weighted average shares outstanding.|GAAP vs. Non-GAAP Earnings|TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.",
#  'P/E Ratio (TTM, GAAP)|P/E Ratio (TTM, GAAP)|GAAP P/E is a relative valuation measure used to determine if a stock is expensive in relation to its peers. It is calculated by dividing the current stock price by the sum of the Diluted Earnings Per Share from continuing operations BEFORE Extraordinary Items and Accounting Changes over the last reported 12 months.|GAAP vs. Non-GAAP Earnings|TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.',
#  'Annual Dividend/Yield|Annual Dividend/Yield|Annual Dividend is calculated by multiplying the announced next regular dividend amount times the annual payment frequency. If no new dividend has been announced, the most recent dividend is used. If dividend payments are inconsistent, as with many ADRs, the annual dividend is calculated by totaling the regular dividends paid over the trailing 12 months. Annual Dividend/yield calculations do not guarantee or imply future payment of dividends.',
#  'Ex-dividend Date',
#  'Dividend Pay Date',
#  "Beta|Beta|The measure of a security's volatility in relation to the S&P 500. Beta less than 1 means the security's price or NAV has been less volatile than the market. Beta greater than 1 means the security's price or NAV has been more volatile than the market.",
#  '% Held by Institutions|% Held by Institutions|Percentage of outstanding shares that are owned by institutional investors. Calculated from current quarterly filing as of today.',
#  'Short Interest|Short Interest|The number of shares of a security that have been sold short by investors. It is typically expressed as a percentage of the total number of shares outstanding and is reported on a monthly basis.| |(% of float 10/31/22)',
#  'Market Edge Opinion:',
#  'Score:']

# %%
dts
# Out:
# [<dt>Closing Price</dt>,
#  <dt>Day's Change</dt>,
#  <dt>Bid</dt>,
#  <dt>Ask</dt>,
#  <dt>B/A Size</dt>,
#  <dt>Day's High</dt>,
#  <dt>Day's Low</dt>,
#  <dt>Volume<div class="ui-tooltip ui-allow-hover"><a class="volumeDetails ui-allow-hover" data-mouseenteraction="openTooltip" data-mouseleaveaction="openTooltip" href="javascript:void(0);">(Below Average)</a><div class="ui-tooltip-content shadow boxshadow ui-open-down ui-position-right"><div class="volume-details"><dl><dt>Volume:</dt><dd>49,207,165</dd><br/><dt>10-day average volume:</dt><dd>57,771,720</dd></dl></div></div><div class="ui-arrow"></div></div></dt>,
#  <dt>Volume:</dt>,
#  <dt>10-day average volume:</dt>,
#  <dt>Prev Close</dt>,
#  <dt>Today's Open</dt>,
#  <dt>Day's Range</dt>,
#  <dt>Avg Vol (10-day)</dt>,
#  <dt>Last (time)</dt>,
#  <dt>Last (size)</dt>,
#  <dt>52-Wk Range<br/>108.13 - 346.47</dt>,
#  <dt><div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "% Above Low"]}' href="#">% Above Low</a><div class="ui-tooltip-content shadow boxshadow ui-open-up ui-position-left click"><h4 class="heading heading-3">% Above Low</h4><p>The current share price compared to the 52-week low.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div></dt>,
#  <dt><div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "Historical Volatility"]}' href="#">Historical Volatility</a><div class="ui-tooltip-content shadow boxshadow ui-open-up ui-position-left click"><h4 class="heading heading-3">Historical Volatility</h4><p>The volatility of a stock over a given time period. It is calculated by determining the average standard deviation from the average price of the stock over one month or 21 business days. Historical volatility can be compared with implied volatility to determine if a stock's options are over- or undervalued.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div></dt>,
#  <dt>Market Cap</dt>,
#  <dt>Shares Outstanding</dt>,
#  <dt><div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "EPS (TTM, GAAP)", "GAAP vs. Non-GAAP Earnings"]}' href="#">EPS (TTM, GAAP)</a><div class="ui-tooltip-content shadow boxshadow ui-open-left ui-position-center click"><h4 class="heading heading-3">EPS (TTM, GAAP)</h4><p>GAAP EPS (TTM) refers to a company's earnings per share (EPS) for the trailing twelve-month (TTM) period. EPS is calculated by dividing the adjusted income available to common stockholders for the trailing twelve months by the trailing twelve-month diluted weighted average shares outstanding.</p><h4 class="heading heading-3">GAAP vs. Non-GAAP Earnings</h4><p>TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div></dt>,
#  <dt><div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "P/E Ratio (TTM, GAAP)", "GAAP vs. Non-GAAP Earnings"]}' href="#">P/E Ratio (TTM, GAAP)</a><div class="ui-tooltip-content shadow boxshadow ui-open-left ui-position-center click"><h4 class="heading heading-3">P/E Ratio (TTM, GAAP)</h4><p>GAAP P/E is a relative valuation measure used to determine if a stock is expensive in relation to its peers. It is calculated by dividing the current stock price by the sum of the Diluted Earnings Per Share from continuing operations BEFORE Extraordinary Items and Accounting Changes over the last reported 12 months.</p><h4 class="heading heading-3">GAAP vs. Non-GAAP Earnings</h4><p>TD Ameritrade displays two types of stock earnings numbers, which are calculated differently and may report different values for the same period. GAAP earnings are the official numbers reported by a company, and non-GAAP earnings are adjusted to be more readable in earnings history and forecasts.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div></dt>,
#  <dt><div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "Annual Dividend/Yield"]}' href="#">Annual Dividend/Yield</a><div class="ui-tooltip-content shadow boxshadow ui-open-left ui-position-center click"><h4 class="heading heading-3">Annual Dividend/Yield</h4><p>Annual Dividend is calculated by multiplying the announced next regular dividend amount times the annual payment frequency. If no new dividend has been announced, the most recent dividend is used. If dividend payments are inconsistent, as with many ADRs, the annual dividend is calculated by totaling the regular dividends paid over the trailing 12 months. Annual Dividend/yield calculations do not guarantee or imply future payment of dividends.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div></dt>,
#  <dt>Ex-dividend Date</dt>,
#  <dt>Dividend Pay Date</dt>,
#  <dt><div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "Beta"]}' href="#">Beta</a><div class="ui-tooltip-content shadow boxshadow ui-open-left ui-position-center click"><h4 class="heading heading-3">Beta</h4><p>The measure of a security's volatility in relation to the S&amp;P 500. Beta less than 1 means the security's price or NAV has been less volatile than the market. Beta greater than 1 means the security's price or NAV has been more volatile than the market.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div></dt>,
#  <dt><div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "% Held by Institutions"]}' href="#">% Held by Institutions</a><div class="ui-tooltip-content shadow boxshadow ui-open-left ui-position-center click"><h4 class="heading heading-3">% Held by Institutions</h4><p>Percentage of outstanding shares that are owned by institutional investors. Calculated from current quarterly filing as of today.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div></dt>,
#  <dt><div class="ui-tooltip ui-on-click ui-definition-link"><div class="closer" data-clickaction="openTooltip"></div><a class="definition-link" data-clickaction="openTooltip" data-sitevendortrack='{"actionName": "unaffiliatedLinkClick", "details": ["definition", "Short Interest"]}' href="#">Short Interest</a><div class="ui-tooltip-content shadow boxshadow ui-open-left ui-position-center click"><h4 class="heading heading-3">Short Interest</h4><p>The number of shares of a security that have been sold short by investors. It is typically expressed as a percentage of the total number of shares outstanding and is reported on a monthly basis.</p><div class="close-button" data-clickaction="openTooltip"><span class="iconWrapper bold close-popup-small action-icon"><span class="icon close-popup-small"></span></span></div></div><div class="ui-arrow"></div></div> <small>(% of float 10/31/22)</small></dt>,
#  <dt>Market Edge Opinion:</dt>,
#  <dt>Score:</dt>]

# %%
driver.quit()
